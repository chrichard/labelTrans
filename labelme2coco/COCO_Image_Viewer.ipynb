# %% [markdown]
# # COCO Image Viewer
# This notebook will allow you to view details about a COCO dataset and preview segmentations on annotated images.
# Learn more about it at: http://cocodataset.org/

# %%
import IPython
import os
import json
import random
import numpy as np
import requests
from io import BytesIO
from math import trunc
from PIL import Image as PILImage
from PIL import ImageDraw as PILImageDraw

# %%
# Load the dataset json
class CocoDataset():
    def __init__(self, annotation_path, image_dir):
        self.annotation_path = annotation_path
        self.image_dir = image_dir
        self.colors = ['blue', 'purple', 'red', 'green', 'orange', 'salmon', 'pink', 'gold',
                       'orchid', 'slateblue', 'limegreen', 'seagreen', 'darkgreen', 'olive',
                       'teal', 'aquamarine', 'steelblue', 'powderblue', 'dodgerblue', 'navy',
                       'magenta', 'sienna', 'maroon']

        json_file = open(self.annotation_path)
        self.coco = json.load(json_file)
        json_file.close()

        self.process_info()
        self.process_licenses()
        self.process_categories()
        self.process_images()
        self.process_segmentations()

    def display_info(self):
        print('Dataset Info:')
        print('=============')
        if self.info is None:
            return
        for key, item in self.info.items():
            print('  {}: {}'.format(key, item))

        requirements = [['description', str],
                        ['url', str],
                        ['version', str],
                        ['year', int],
                        ['contributor', str],
                        ['date_created', str]]
        for req, req_type in requirements:
            if req not in self.info:
                print('ERROR: {} is missing'.format(req))
            elif type(self.info[req]) != req_type:
                print('ERROR: {} should be type {}'.format(req, str(req_type)))
        print('')

    def display_licenses(self):
        print('Licenses:')
        print('=========')

        if self.licenses is None:
            return
        requirements = [['id', int],
                        ['url', str],
                        ['name', str]]
        for license in self.licenses:
            for key, item in license.items():
                print('  {}: {}'.format(key, item))
            for req, req_type in requirements:
                if req not in license:
                    print('ERROR: {} is missing'.format(req))
                elif type(license[req]) != req_type:
                    print('ERROR: {} should be type {}'.format(
                        req, str(req_type)))
            print('')
        print('')

    def display_categories(self):
        print('Categories:')
        print('=========')
        for sc_key, sc_val in self.super_categories.items():
            print('  super_category: {}'.format(sc_key))
            for cat_id in sc_val:
                print('    id {}: {}'.format(
                    cat_id, self.categories[cat_id]['name']))
            print('')

    def display_image(self, image_id, show_polys=True, show_bbox=True, show_crowds=True, use_url=False):
        print('Image:')
        print('======')
        if image_id == 'random':
            image_id = random.choice(list(self.images.keys()))

        # Print the image info
        image = self.images[image_id]
        for key, val in image.items():
            print('  {}: {}'.format(key, val))

        # Open the image
        if use_url:
            image_path = image['coco_url']
            response = requests.get(image_path)
            image = PILImage.open(BytesIO(response.content))

        else:
            # image_path = os.path.join(self.image_dir, image['file_name'])
            image_path = "{}/{}".format(self.image_dir, image['file_name'])
            print(image_path)
            image = PILImage.open(image_path)

        # Calculate the size and adjusted display size
        max_width = 600
        image_width, image_height = image.size
        adjusted_width = min(image_width, max_width)
        adjusted_ratio = adjusted_width / image_width
        adjusted_height = adjusted_ratio * image_height

        # Create list of polygons to be drawn
        polygons = {}
        bbox_polygons = {}
        rle_regions = {}
        poly_colors = {}
        bbox_categories = {}
        print('  segmentations ({}):'.format(
            len(self.segmentations[image_id])))
        for i, segm in enumerate(self.segmentations[image_id]):
            polygons_list = []
            if segm['iscrowd'] != 0:
                # Gotta decode the RLE
                px = 0
                x, y = 0, 0
                rle_list = []
                for j, counts in enumerate(segm['segmentation']['counts']):
                    if j % 2 == 0:
                        # Empty pixels
                        px += counts
                    else:
                        # Need to draw on these pixels, since we are drawing in vector form,
                        # we need to draw horizontal lines on the image
                        x_start = trunc(
                            trunc(px / image_height) * adjusted_ratio)
                        y_start = trunc(px % image_height * adjusted_ratio)
                        px += counts
                        x_end = trunc(trunc(px / image_height)
                                      * adjusted_ratio)
                        y_end = trunc(px % image_height * adjusted_ratio)
                        if x_end == x_start:
                            # This is only on one line
                            rle_list.append(
                                {'x': x_start, 'y': y_start, 'width': 1, 'height': (y_end - y_start)})
                        if x_end > x_start:
                            # This spans more than one line
                            # Insert top line first
                            rle_list.append(
                                {'x': x_start, 'y': y_start, 'width': 1, 'height': (image_height - y_start)})

                            # Insert middle lines if needed
                            lines_spanned = x_end - x_start + 1  # total number of lines spanned
                            full_lines_to_insert = lines_spanned - 2
                            if full_lines_to_insert > 0:
                                full_lines_to_insert = trunc(
                                    full_lines_to_insert * adjusted_ratio)
                                rle_list.append(
                                    {'x': (x_start + 1), 'y': 0, 'width': full_lines_to_insert, 'height': image_height})

                            # Insert bottom line
                            rle_list.append(
                                {'x': x_end, 'y': 0, 'width': 1, 'height': y_end})
                if len(rle_list) > 0:
                    rle_regions[segm['id']] = rle_list
            else:
                # Add the polygon segmentation
                for segmentation_points in segm['segmentation']:
                    segmentation_points = np.multiply(
                        segmentation_points, adjusted_ratio).astype(int)
                    polygons_list.append(
                        str(segmentation_points).lstrip('[').rstrip(']'))
            polygons[segm['id']] = polygons_list
            if i < len(self.colors):
                poly_colors[segm['id']] = self.colors[i]
            else:
                poly_colors[segm['id']] = 'white'

            bbox = segm['bbox']
            bbox_points = [bbox[0], bbox[1], bbox[0] + bbox[2], bbox[1],
                           bbox[0] + bbox[2], bbox[1] +
                           bbox[3], bbox[0], bbox[1] + bbox[3],
                           bbox[0], bbox[1]]
            bbox_points = np.multiply(bbox_points, adjusted_ratio).astype(int)
            bbox_polygons[segm['id']] = str(
                bbox_points).lstrip('[').rstrip(']')
            bbox_categories[segm['id']] = self.categories[segm['category_id']]
            # Print details
            print('    {}:{}:{}'.format(
                segm['id'], poly_colors[segm['id']], self.categories[segm['category_id']]))

        # Draw segmentation polygons on image
        html = '<div class="container" style="position:relative;">'
        html += '<img src="{}" style="position:relative;top:0px;left:0px;width:{}px;">'.format(
            image_path, adjusted_width)
        html += '<div class="svgclass"><svg width="{}" height="{}">'.format(
            adjusted_width, adjusted_height)

        if show_polys:
            for seg_id, points_list in polygons.items():
                fill_color = poly_colors[seg_id]
                stroke_color = poly_colors[seg_id]
                for points in points_list:
                    html += '<polygon points="{}" style="fill:{}; stroke:{}; stroke-width:1; fill-opacity:0.5" />'.format(
                        points, fill_color, stroke_color)

        if show_crowds:
            for seg_id, rect_list in rle_regions.items():
                fill_color = poly_colors[seg_id]
                stroke_color = poly_colors[seg_id]
                for rect_def in rect_list:
                    x, y = rect_def['x'], rect_def['y']
                    w, h = rect_def['width'], rect_def['height']
                    html += '<rect x="{}" y="{}" width="{}" height="{}" style="fill:{}; stroke:{}; stroke-width:1; fill-opacity:0.5; stroke-opacity:0.5" />'.format(
                        x, y, w, h, fill_color, stroke_color)

        if show_bbox:
            for seg_id, points in bbox_polygons.items():
                x, y = [int(i) for i in points.split()[:2]]
                html += '<text x="{}" y="{}" fill="yellow">{}</text>'.format(
                    x, y, bbox_categories[seg_id]["name"])
                fill_color = poly_colors[seg_id]
                stroke_color = poly_colors[seg_id]
                html += '<polygon points="{}" style="fill:{}; stroke:{}; stroke-width:1; fill-opacity:0" />'.format(
                    points, fill_color, stroke_color)

        html += '</svg></div>'
        html += '</div>'
        html += '<style>'
        html += '.svgclass { position:absolute; top:0px; left:0px;}'
        html += '</style>'
        return html

    def process_info(self):
        self.info = self.coco.get('info')

    def process_licenses(self):
        self.licenses = self.coco.get('licenses')

    def process_categories(self):
        self.categories = {}
        self.super_categories = {}
        for category in self.coco['categories']:
            cat_id = category['id']
            super_category = category['supercategory']

            # Add category to the categories dict
            if cat_id not in self.categories:
                self.categories[cat_id] = category
            else:
                print("ERROR: Skipping duplicate category id: {}".format(category))

            # Add category to super_categories dict
            if super_category not in self.super_categories:
                # Create a new set with the category id
                self.super_categories[super_category] = {cat_id}
            else:
                self.super_categories[super_category] |= {
                    cat_id}  # Add category id to the set

    def process_images(self):
        self.images = {}
        for image in self.coco['images']:
            image_id = image['id']
            if image_id in self.images:
                print("ERROR: Skipping duplicate image id: {}".format(image))
            else:
                self.images[image_id] = image

    def process_segmentations(self):
        self.segmentations = {}
        for segmentation in self.coco['annotations']:
            image_id = segmentation['image_id']
            if image_id not in self.segmentations:
                self.segmentations[image_id] = []
            self.segmentations[image_id].append(segmentation)

# %%
annotation_path = "trainval.json"
image_dir = "images"

image_dir = '/tao/maskrcnn/data/raw-data/validating_data/'
annotation_path = 'coco_anno.json'

image_dir = '/AI/DLDataSet/cityscape/cityscape_labelme/val2017/'
annotation_path = '/AI/DLDataSet/cityscape/cityscape_labelme/annotations/instances_val2017.json'

coco_dataset = CocoDataset(annotation_path, image_dir)
coco_dataset.display_info()
coco_dataset.display_licenses()
coco_dataset.display_categories()
# Out:
# Dataset Info:
# =============
# Licenses:
# =========
# Categories:
# =========
#   super_category: bicycle
#     id 1: bicycle
#
#   super_category: bicyclegroup
#     id 2: bicyclegroup
#
#   super_category: bridge
#     id 3: bridge
#
#   super_category: building
#     id 4: building
#
#   super_category: bus
#     id 5: bus
#
#   super_category: car
#     id 6: car
#
#   super_category: caravan
#     id 7: caravan
#
#   super_category: cargroup
#     id 8: cargroup
#
#   super_category: dynamic
#     id 9: dynamic
#
#   super_category: ego vehicle
#     id 10: ego vehicle
#
#   super_category: fence
#     id 11: fence
#
#   super_category: ground
#     id 12: ground
#
#   super_category: guard rail
#     id 13: guard rail
#
#   super_category: license plate
#     id 14: license plate
#
#   super_category: motorcycle
#     id 15: motorcycle
#
#   super_category: out of roi
#     id 16: out of roi
#
#   super_category: parking
#     id 17: parking
#
#   super_category: person
#     id 18: person
#
#   super_category: persongroup
#     id 19: persongroup
#
#   super_category: pole
#     id 20: pole
#
#   super_category: polegroup
#     id 21: polegroup
#
#   super_category: rail track
#     id 22: rail track
#
#   super_category: rectification border
#     id 23: rectification border
#
#   super_category: rider
#     id 24: rider
#
#   super_category: ridergroup
#     id 25: ridergroup
#
#   super_category: road
#     id 26: road
#
#   super_category: sidewalk
#     id 27: sidewalk
#
#   super_category: sky
#     id 28: sky
#
#   super_category: static
#     id 29: static
#
#   super_category: terrain
#     id 30: terrain
#
#   super_category: traffic light
#     id 31: traffic light
#
#   super_category: traffic sign
#     id 32: traffic sign
#
#   super_category: trailer
#     id 33: trailer
#
#   super_category: train
#     id 34: train
#
#   super_category: truck
#     id 35: truck
#
#   super_category: vegetation
#     id 36: vegetation
#
#   super_category: wall
#     id 37: wall

# %%
for k, v in coco_dataset.images.items():
    print(k, v)
# Out:
# 0 {'height': 512, 'width': 1024, 'id': 0, 'file_name': 'frankfurt_000001_002759_leftImg8bit.png.jpg'}
# 1 {'height': 512, 'width': 1024, 'id': 1, 'file_name': 'frankfurt_000001_035144_leftImg8bit.png.jpg'}
# 2 {'height': 512, 'width': 1024, 'id': 2, 'file_name': 'frankfurt_000001_030310_leftImg8bit.png.jpg'}
# 3 {'height': 512, 'width': 1024, 'id': 3, 'file_name': 'munster_000019_000019_leftImg8bit.png.jpg'}
# 4 {'height': 512, 'width': 1024, 'id': 4, 'file_name': 'frankfurt_000001_058176_leftImg8bit.png.jpg'}
# 5 {'height': 512, 'width': 1024, 'id': 5, 'file_name': 'munster_000139_000019_leftImg8bit.png.jpg'}
# 6 {'height': 512, 'width': 1024, 'id': 6, 'file_name': 'lindau_000041_000019_leftImg8bit.png.jpg'}
# 7 {'height': 512, 'width': 1024, 'id': 7, 'file_name': 'frankfurt_000001_021825_leftImg8bit.png.jpg'}
# 8 {'height': 512, 'width': 1024, 'id': 8, 'file_name': 'frankfurt_000001_042384_leftImg8bit.png.jpg'}
# 9 {'height': 512, 'width': 1024, 'id': 9, 'file_name': 'frankfurt_000001_072295_leftImg8bit.png.jpg'}
# 10 {'height': 512, 'width': 1024, 'id': 10, 'file_name': 'munster_000012_000019_leftImg8bit.png.jpg'}
# 11 {'height': 512, 'width': 1024, 'id': 11, 'file_name': 'frankfurt_000001_002512_leftImg8bit.png.jpg'}
# 12 {'height': 512, 'width': 1024, 'id': 12, 'file_name': 'frankfurt_000001_038645_leftImg8bit.png.jpg'}
# 13 {'height': 512, 'width': 1024, 'id': 13, 'file_name': 'frankfurt_000001_019854_leftImg8bit.png.jpg'}
# 14 {'height': 512, 'width': 1024, 'id': 14, 'file_name': 'munster_000105_000019_leftImg8bit.png.jpg'}
# 15 {'height': 512, 'width': 1024, 'id': 15, 'file_name': 'munster_000149_000019_leftImg8bit.png.jpg'}
# 16 {'height': 512, 'width': 1024, 'id': 16, 'file_name': 'lindau_000035_000019_leftImg8bit.png.jpg'}
# 17 {'height': 512, 'width': 1024, 'id': 17, 'file_name': 'munster_000095_000019_leftImg8bit.png.jpg'}
# 18 {'height': 512, 'width': 1024, 'id': 18, 'file_name': 'frankfurt_000000_011007_leftImg8bit.png.jpg'}
# 19 {'height': 512, 'width': 1024, 'id': 19, 'file_name': 'munster_000050_000019_leftImg8bit.png.jpg'}
# 20 {'height': 512, 'width': 1024, 'id': 20, 'file_name': 'lindau_000033_000019_leftImg8bit.png.jpg'}
# 21 {'height': 512, 'width': 1024, 'id': 21, 'file_name': 'frankfurt_000001_064925_leftImg8bit.png.jpg'}
# 22 {'height': 512, 'width': 1024, 'id': 22, 'file_name': 'frankfurt_000001_050149_leftImg8bit.png.jpg'}
# 23 {'height': 512, 'width': 1024, 'id': 23, 'file_name': 'frankfurt_000001_053102_leftImg8bit.png.jpg'}
# 24 {'height': 512, 'width': 1024, 'id': 24, 'file_name': 'frankfurt_000001_046126_leftImg8bit.png.jpg'}
# 25 {'height': 512, 'width': 1024, 'id': 25, 'file_name': 'frankfurt_000000_006589_leftImg8bit.png.jpg'}
# 26 {'height': 512, 'width': 1024, 'id': 26, 'file_name': 'munster_000030_000019_leftImg8bit.png.jpg'}
# 27 {'height': 512, 'width': 1024, 'id': 27, 'file_name': 'frankfurt_000001_070099_leftImg8bit.png.jpg'}
# 28 {'height': 512, 'width': 1024, 'id': 28, 'file_name': 'munster_000160_000019_leftImg8bit.png.jpg'}
# 29 {'height': 512, 'width': 1024, 'id': 29, 'file_name': 'munster_000164_000019_leftImg8bit.png.jpg'}
# 30 {'height': 512, 'width': 1024, 'id': 30, 'file_name': 'munster_000145_000019_leftImg8bit.png.jpg'}
# 31 {'height': 512, 'width': 1024, 'id': 31, 'file_name': 'lindau_000009_000019_leftImg8bit.png.jpg'}
# 32 {'height': 512, 'width': 1024, 'id': 32, 'file_name': 'frankfurt_000001_005898_leftImg8bit.png.jpg'}
# 33 {'height': 512, 'width': 1024, 'id': 33, 'file_name': 'frankfurt_000001_023369_leftImg8bit.png.jpg'}
# 34 {'height': 512, 'width': 1024, 'id': 34, 'file_name': 'frankfurt_000001_067178_leftImg8bit.png.jpg'}
# 35 {'height': 512, 'width': 1024, 'id': 35, 'file_name': 'frankfurt_000001_020046_leftImg8bit.png.jpg'}
# 36 {'height': 512, 'width': 1024, 'id': 36, 'file_name': 'munster_000156_000019_leftImg8bit.png.jpg'}
# 37 {'height': 512, 'width': 1024, 'id': 37, 'file_name': 'munster_000136_000019_leftImg8bit.png.jpg'}
# 38 {'height': 512, 'width': 1024, 'id': 38, 'file_name': 'munster_000129_000019_leftImg8bit.png.jpg'}
# 39 {'height': 512, 'width': 1024, 'id': 39, 'file_name': 'lindau_000024_000019_leftImg8bit.png.jpg'}
# 40 {'height': 512, 'width': 1024, 'id': 40, 'file_name': 'munster_000118_000019_leftImg8bit.png.jpg'}
# 41 {'height': 512, 'width': 1024, 'id': 41, 'file_name': 'frankfurt_000001_067474_leftImg8bit.png.jpg'}
# 42 {'height': 512, 'width': 1024, 'id': 42, 'file_name': 'munster_000148_000019_leftImg8bit.png.jpg'}
# 43 {'height': 512, 'width': 1024, 'id': 43, 'file_name': 'lindau_000032_000019_leftImg8bit.png.jpg'}
# 44 {'height': 512, 'width': 1024, 'id': 44, 'file_name': 'munster_000015_000019_leftImg8bit.png.jpg'}
# 45 {'height': 512, 'width': 1024, 'id': 45, 'file_name': 'frankfurt_000001_037705_leftImg8bit.png.jpg'}
# 46 {'height': 512, 'width': 1024, 'id': 46, 'file_name': 'lindau_000022_000019_leftImg8bit.png.jpg'}
# 47 {'height': 512, 'width': 1024, 'id': 47, 'file_name': 'munster_000041_000019_leftImg8bit.png.jpg'}
# 48 {'height': 512, 'width': 1024, 'id': 48, 'file_name': 'munster_000054_000019_leftImg8bit.png.jpg'}
# 49 {'height': 512, 'width': 1024, 'id': 49, 'file_name': 'frankfurt_000001_027325_leftImg8bit.png.jpg'}
# 50 {'height': 512, 'width': 1024, 'id': 50, 'file_name': 'munster_000060_000019_leftImg8bit.png.jpg'}
# 51 {'height': 512, 'width': 1024, 'id': 51, 'file_name': 'munster_000075_000019_leftImg8bit.png.jpg'}
# 52 {'height': 512, 'width': 1024, 'id': 52, 'file_name': 'frankfurt_000001_012738_leftImg8bit.png.jpg'}
# 53 {'height': 512, 'width': 1024, 'id': 53, 'file_name': 'frankfurt_000001_065850_leftImg8bit.png.jpg'}
# 54 {'height': 512, 'width': 1024, 'id': 54, 'file_name': 'lindau_000020_000019_leftImg8bit.png.jpg'}
# 55 {'height': 512, 'width': 1024, 'id': 55, 'file_name': 'frankfurt_000001_008200_leftImg8bit.png.jpg'}
# 56 {'height': 512, 'width': 1024, 'id': 56, 'file_name': 'munster_000107_000019_leftImg8bit.png.jpg'}
# 57 {'height': 512, 'width': 1024, 'id': 57, 'file_name': 'frankfurt_000001_055306_leftImg8bit.png.jpg'}
# 58 {'height': 512, 'width': 1024, 'id': 58, 'file_name': 'frankfurt_000001_057478_leftImg8bit.png.jpg'}
# 59 {'height': 512, 'width': 1024, 'id': 59, 'file_name': 'lindau_000019_000019_leftImg8bit.png.jpg'}
# 60 {'height': 512, 'width': 1024, 'id': 60, 'file_name': 'frankfurt_000001_054884_leftImg8bit.png.jpg'}
# 61 {'height': 512, 'width': 1024, 'id': 61, 'file_name': 'munster_000117_000019_leftImg8bit.png.jpg'}
# 62 {'height': 512, 'width': 1024, 'id': 62, 'file_name': 'frankfurt_000000_000576_leftImg8bit.png.jpg'}
# 63 {'height': 512, 'width': 1024, 'id': 63, 'file_name': 'munster_000071_000019_leftImg8bit.png.jpg'}
# 64 {'height': 512, 'width': 1024, 'id': 64, 'file_name': 'munster_000155_000019_leftImg8bit.png.jpg'}
# 65 {'height': 512, 'width': 1024, 'id': 65, 'file_name': 'frankfurt_000001_071288_leftImg8bit.png.jpg'}
# 66 {'height': 512, 'width': 1024, 'id': 66, 'file_name': 'frankfurt_000001_044413_leftImg8bit.png.jpg'}
# 67 {'height': 512, 'width': 1024, 'id': 67, 'file_name': 'munster_000053_000019_leftImg8bit.png.jpg'}
# 68 {'height': 512, 'width': 1024, 'id': 68, 'file_name': 'frankfurt_000001_007285_leftImg8bit.png.jpg'}
# 69 {'height': 512, 'width': 1024, 'id': 69, 'file_name': 'munster_000010_000019_leftImg8bit.png.jpg'}
# 70 {'height': 512, 'width': 1024, 'id': 70, 'file_name': 'munster_000165_000019_leftImg8bit.png.jpg'}
# 71 {'height': 512, 'width': 1024, 'id': 71, 'file_name': 'frankfurt_000001_012870_leftImg8bit.png.jpg'}
# 72 {'height': 512, 'width': 1024, 'id': 72, 'file_name': 'frankfurt_000000_002196_leftImg8bit.png.jpg'}
# 73 {'height': 512, 'width': 1024, 'id': 73, 'file_name': 'lindau_000000_000019_leftImg8bit.png.jpg'}
# 74 {'height': 512, 'width': 1024, 'id': 74, 'file_name': 'munster_000134_000019_leftImg8bit.png.jpg'}
# 75 {'height': 512, 'width': 1024, 'id': 75, 'file_name': 'munster_000098_000019_leftImg8bit.png.jpg'}
# 76 {'height': 512, 'width': 1024, 'id': 76, 'file_name': 'munster_000061_000019_leftImg8bit.png.jpg'}
# 77 {'height': 512, 'width': 1024, 'id': 77, 'file_name': 'frankfurt_000001_020693_leftImg8bit.png.jpg'}
# 78 {'height': 512, 'width': 1024, 'id': 78, 'file_name': 'frankfurt_000001_011162_leftImg8bit.png.jpg'}
# 79 {'height': 512, 'width': 1024, 'id': 79, 'file_name': 'munster_000016_000019_leftImg8bit.png.jpg'}
# 80 {'height': 512, 'width': 1024, 'id': 80, 'file_name': 'frankfurt_000000_003357_leftImg8bit.png.jpg'}
# 81 {'height': 512, 'width': 1024, 'id': 81, 'file_name': 'munster_000064_000019_leftImg8bit.png.jpg'}
# 82 {'height': 512, 'width': 1024, 'id': 82, 'file_name': 'frankfurt_000001_051807_leftImg8bit.png.jpg'}
# 83 {'height': 512, 'width': 1024, 'id': 83, 'file_name': 'munster_000008_000019_leftImg8bit.png.jpg'}
# 84 {'height': 512, 'width': 1024, 'id': 84, 'file_name': 'frankfurt_000001_010156_leftImg8bit.png.jpg'}
# 85 {'height': 512, 'width': 1024, 'id': 85, 'file_name': 'frankfurt_000001_028590_leftImg8bit.png.jpg'}
# 86 {'height': 512, 'width': 1024, 'id': 86, 'file_name': 'lindau_000034_000019_leftImg8bit.png.jpg'}
# 87 {'height': 512, 'width': 1024, 'id': 87, 'file_name': 'munster_000002_000019_leftImg8bit.png.jpg'}
# 88 {'height': 512, 'width': 1024, 'id': 88, 'file_name': 'frankfurt_000000_018797_leftImg8bit.png.jpg'}
# 89 {'height': 512, 'width': 1024, 'id': 89, 'file_name': 'lindau_000052_000019_leftImg8bit.png.jpg'}
# 90 {'height': 512, 'width': 1024, 'id': 90, 'file_name': 'lindau_000056_000019_leftImg8bit.png.jpg'}
# 91 {'height': 512, 'width': 1024, 'id': 91, 'file_name': 'frankfurt_000000_015676_leftImg8bit.png.jpg'}
# 92 {'height': 512, 'width': 1024, 'id': 92, 'file_name': 'munster_000141_000019_leftImg8bit.png.jpg'}
# 93 {'height': 512, 'width': 1024, 'id': 93, 'file_name': 'frankfurt_000001_038245_leftImg8bit.png.jpg'}
# 94 {'height': 512, 'width': 1024, 'id': 94, 'file_name': 'frankfurt_000001_077092_leftImg8bit.png.jpg'}
# 95 {'height': 512, 'width': 1024, 'id': 95, 'file_name': 'frankfurt_000000_013382_leftImg8bit.png.jpg'}
# 96 {'height': 512, 'width': 1024, 'id': 96, 'file_name': 'frankfurt_000001_083199_leftImg8bit.png.jpg'}
# 97 {'height': 512, 'width': 1024, 'id': 97, 'file_name': 'munster_000081_000019_leftImg8bit.png.jpg'}
# 98 {'height': 512, 'width': 1024, 'id': 98, 'file_name': 'lindau_000028_000019_leftImg8bit.png.jpg'}
# 99 {'height': 512, 'width': 1024, 'id': 99, 'file_name': 'frankfurt_000001_029600_leftImg8bit.png.jpg'}
# 100 {'height': 512, 'width': 1024, 'id': 100, 'file_name': 'frankfurt_000001_048654_leftImg8bit.png.jpg'}
# 101 {'height': 512, 'width': 1024, 'id': 101, 'file_name': 'frankfurt_000000_010763_leftImg8bit.png.jpg'}
# 102 {'height': 512, 'width': 1024, 'id': 102, 'file_name': 'frankfurt_000001_064305_leftImg8bit.png.jpg'}
# 103 {'height': 512, 'width': 1024, 'id': 103, 'file_name': 'munster_000154_000019_leftImg8bit.png.jpg'}
# 104 {'height': 512, 'width': 1024, 'id': 104, 'file_name': 'frankfurt_000001_012038_leftImg8bit.png.jpg'}
# 105 {'height': 512, 'width': 1024, 'id': 105, 'file_name': 'frankfurt_000001_067295_leftImg8bit.png.jpg'}
# 106 {'height': 512, 'width': 1024, 'id': 106, 'file_name': 'frankfurt_000001_059789_leftImg8bit.png.jpg'}
# 107 {'height': 512, 'width': 1024, 'id': 107, 'file_name': 'munster_000091_000019_leftImg8bit.png.jpg'}
# 108 {'height': 512, 'width': 1024, 'id': 108, 'file_name': 'frankfurt_000001_041074_leftImg8bit.png.jpg'}
# 109 {'height': 512, 'width': 1024, 'id': 109, 'file_name': 'frankfurt_000001_075984_leftImg8bit.png.jpg'}
# 110 {'height': 512, 'width': 1024, 'id': 110, 'file_name': 'munster_000003_000019_leftImg8bit.png.jpg'}
# 111 {'height': 512, 'width': 1024, 'id': 111, 'file_name': 'frankfurt_000001_025512_leftImg8bit.png.jpg'}
# 112 {'height': 512, 'width': 1024, 'id': 112, 'file_name': 'lindau_000037_000019_leftImg8bit.png.jpg'}
# 113 {'height': 512, 'width': 1024, 'id': 113, 'file_name': 'frankfurt_000001_004736_leftImg8bit.png.jpg'}
# 114 {'height': 512, 'width': 1024, 'id': 114, 'file_name': 'frankfurt_000001_080091_leftImg8bit.png.jpg'}
# 115 {'height': 512, 'width': 1024, 'id': 115, 'file_name': 'frankfurt_000001_029236_leftImg8bit.png.jpg'}
# 116 {'height': 512, 'width': 1024, 'id': 116, 'file_name': 'frankfurt_000000_008451_leftImg8bit.png.jpg'}
# 117 {'height': 512, 'width': 1024, 'id': 117, 'file_name': 'munster_000001_000019_leftImg8bit.png.jpg'}
# 118 {'height': 512, 'width': 1024, 'id': 118, 'file_name': 'munster_000127_000019_leftImg8bit.png.jpg'}
# 119 {'height': 512, 'width': 1024, 'id': 119, 'file_name': 'frankfurt_000001_005410_leftImg8bit.png.jpg'}
# 120 {'height': 512, 'width': 1024, 'id': 120, 'file_name': 'munster_000147_000019_leftImg8bit.png.jpg'}
# 121 {'height': 512, 'width': 1024, 'id': 121, 'file_name': 'frankfurt_000001_033655_leftImg8bit.png.jpg'}
# 122 {'height': 512, 'width': 1024, 'id': 122, 'file_name': 'frankfurt_000001_010444_leftImg8bit.png.jpg'}
# 123 {'height': 512, 'width': 1024, 'id': 123, 'file_name': 'munster_000170_000019_leftImg8bit.png.jpg'}
# 124 {'height': 512, 'width': 1024, 'id': 124, 'file_name': 'frankfurt_000000_020880_leftImg8bit.png.jpg'}
# 125 {'height': 512, 'width': 1024, 'id': 125, 'file_name': 'frankfurt_000000_013942_leftImg8bit.png.jpg'}
# 126 {'height': 512, 'width': 1024, 'id': 126, 'file_name': 'frankfurt_000001_068682_leftImg8bit.png.jpg'}
# 127 {'height': 512, 'width': 1024, 'id': 127, 'file_name': 'lindau_000046_000019_leftImg8bit.png.jpg'}
# 128 {'height': 512, 'width': 1024, 'id': 128, 'file_name': 'lindau_000013_000019_leftImg8bit.png.jpg'}
# 129 {'height': 512, 'width': 1024, 'id': 129, 'file_name': 'munster_000006_000019_leftImg8bit.png.jpg'}
# 130 {'height': 512, 'width': 1024, 'id': 130, 'file_name': 'frankfurt_000001_041664_leftImg8bit.png.jpg'}
# 131 {'height': 512, 'width': 1024, 'id': 131, 'file_name': 'lindau_000045_000019_leftImg8bit.png.jpg'}
# 132 {'height': 512, 'width': 1024, 'id': 132, 'file_name': 'frankfurt_000001_065160_leftImg8bit.png.jpg'}
# 133 {'height': 512, 'width': 1024, 'id': 133, 'file_name': 'frankfurt_000000_013067_leftImg8bit.png.jpg'}
# 134 {'height': 512, 'width': 1024, 'id': 134, 'file_name': 'frankfurt_000001_028232_leftImg8bit.png.jpg'}
# 135 {'height': 512, 'width': 1024, 'id': 135, 'file_name': 'frankfurt_000001_009058_leftImg8bit.png.jpg'}
# 136 {'height': 512, 'width': 1024, 'id': 136, 'file_name': 'frankfurt_000001_066092_leftImg8bit.png.jpg'}
# 137 {'height': 512, 'width': 1024, 'id': 137, 'file_name': 'munster_000055_000019_leftImg8bit.png.jpg'}
# 138 {'height': 512, 'width': 1024, 'id': 138, 'file_name': 'munster_000131_000019_leftImg8bit.png.jpg'}
# 139 {'height': 512, 'width': 1024, 'id': 139, 'file_name': 'munster_000046_000019_leftImg8bit.png.jpg'}
# 140 {'height': 512, 'width': 1024, 'id': 140, 'file_name': 'frankfurt_000001_060135_leftImg8bit.png.jpg'}
# 141 {'height': 512, 'width': 1024, 'id': 141, 'file_name': 'lindau_000040_000019_leftImg8bit.png.jpg'}
# 142 {'height': 512, 'width': 1024, 'id': 142, 'file_name': 'frankfurt_000001_005703_leftImg8bit.png.jpg'}
# 143 {'height': 512, 'width': 1024, 'id': 143, 'file_name': 'munster_000115_000019_leftImg8bit.png.jpg'}
# 144 {'height': 512, 'width': 1024, 'id': 144, 'file_name': 'munster_000043_000019_leftImg8bit.png.jpg'}
# 145 {'height': 512, 'width': 1024, 'id': 145, 'file_name': 'frankfurt_000000_011461_leftImg8bit.png.jpg'}
# 146 {'height': 512, 'width': 1024, 'id': 146, 'file_name': 'munster_000029_000019_leftImg8bit.png.jpg'}
# 147 {'height': 512, 'width': 1024, 'id': 147, 'file_name': 'munster_000072_000019_leftImg8bit.png.jpg'}
# 148 {'height': 512, 'width': 1024, 'id': 148, 'file_name': 'lindau_000053_000019_leftImg8bit.png.jpg'}
# 149 {'height': 512, 'width': 1024, 'id': 149, 'file_name': 'munster_000014_000019_leftImg8bit.png.jpg'}
# 150 {'height': 512, 'width': 1024, 'id': 150, 'file_name': 'frankfurt_000001_005184_leftImg8bit.png.jpg'}
# 151 {'height': 512, 'width': 1024, 'id': 151, 'file_name': 'frankfurt_000001_014741_leftImg8bit.png.jpg'}
# 152 {'height': 512, 'width': 1024, 'id': 152, 'file_name': 'frankfurt_000001_055709_leftImg8bit.png.jpg'}
# 153 {'height': 512, 'width': 1024, 'id': 153, 'file_name': 'frankfurt_000001_077434_leftImg8bit.png.jpg'}
# 154 {'height': 512, 'width': 1024, 'id': 154, 'file_name': 'frankfurt_000001_082466_leftImg8bit.png.jpg'}
# 155 {'height': 512, 'width': 1024, 'id': 155, 'file_name': 'lindau_000007_000019_leftImg8bit.png.jpg'}
# 156 {'height': 512, 'width': 1024, 'id': 156, 'file_name': 'frankfurt_000001_044787_leftImg8bit.png.jpg'}
# 157 {'height': 512, 'width': 1024, 'id': 157, 'file_name': 'frankfurt_000001_066574_leftImg8bit.png.jpg'}
# 158 {'height': 512, 'width': 1024, 'id': 158, 'file_name': 'munster_000167_000019_leftImg8bit.png.jpg'}
# 159 {'height': 512, 'width': 1024, 'id': 159, 'file_name': 'frankfurt_000001_004859_leftImg8bit.png.jpg'}
# 160 {'height': 512, 'width': 1024, 'id': 160, 'file_name': 'frankfurt_000001_020287_leftImg8bit.png.jpg'}
# 161 {'height': 512, 'width': 1024, 'id': 161, 'file_name': 'frankfurt_000001_017842_leftImg8bit.png.jpg'}
# 162 {'height': 512, 'width': 1024, 'id': 162, 'file_name': 'frankfurt_000001_051516_leftImg8bit.png.jpg'}
# 163 {'height': 512, 'width': 1024, 'id': 163, 'file_name': 'frankfurt_000001_011715_leftImg8bit.png.jpg'}
# 164 {'height': 512, 'width': 1024, 'id': 164, 'file_name': 'frankfurt_000001_075296_leftImg8bit.png.jpg'}
# 165 {'height': 512, 'width': 1024, 'id': 165, 'file_name': 'munster_000124_000019_leftImg8bit.png.jpg'}
# 166 {'height': 512, 'width': 1024, 'id': 166, 'file_name': 'frankfurt_000001_007407_leftImg8bit.png.jpg'}
# 167 {'height': 512, 'width': 1024, 'id': 167, 'file_name': 'munster_000073_000019_leftImg8bit.png.jpg'}
# 168 {'height': 512, 'width': 1024, 'id': 168, 'file_name': 'frankfurt_000000_001751_leftImg8bit.png.jpg'}
# 169 {'height': 512, 'width': 1024, 'id': 169, 'file_name': 'munster_000059_000019_leftImg8bit.png.jpg'}
# 170 {'height': 512, 'width': 1024, 'id': 170, 'file_name': 'frankfurt_000000_009291_leftImg8bit.png.jpg'}
# 171 {'height': 512, 'width': 1024, 'id': 171, 'file_name': 'lindau_000011_000019_leftImg8bit.png.jpg'}
# 172 {'height': 512, 'width': 1024, 'id': 172, 'file_name': 'frankfurt_000001_009504_leftImg8bit.png.jpg'}
# 173 {'height': 512, 'width': 1024, 'id': 173, 'file_name': 'munster_000024_000019_leftImg8bit.png.jpg'}
# 174 {'height': 512, 'width': 1024, 'id': 174, 'file_name': 'munster_000158_000019_leftImg8bit.png.jpg'}
# 175 {'height': 512, 'width': 1024, 'id': 175, 'file_name': 'munster_000058_000019_leftImg8bit.png.jpg'}
# 176 {'height': 512, 'width': 1024, 'id': 176, 'file_name': 'munster_000056_000019_leftImg8bit.png.jpg'}
# 177 {'height': 512, 'width': 1024, 'id': 177, 'file_name': 'frankfurt_000001_083852_leftImg8bit.png.jpg'}
# 178 {'height': 512, 'width': 1024, 'id': 178, 'file_name': 'frankfurt_000001_068772_leftImg8bit.png.jpg'}
# 179 {'height': 512, 'width': 1024, 'id': 179, 'file_name': 'munster_000135_000019_leftImg8bit.png.jpg'}
# 180 {'height': 512, 'width': 1024, 'id': 180, 'file_name': 'munster_000161_000019_leftImg8bit.png.jpg'}
# 181 {'height': 512, 'width': 1024, 'id': 181, 'file_name': 'lindau_000003_000019_leftImg8bit.png.jpg'}
# 182 {'height': 512, 'width': 1024, 'id': 182, 'file_name': 'frankfurt_000001_064798_leftImg8bit.png.jpg'}
# 183 {'height': 512, 'width': 1024, 'id': 183, 'file_name': 'frankfurt_000000_005543_leftImg8bit.png.jpg'}
# 184 {'height': 512, 'width': 1024, 'id': 184, 'file_name': 'munster_000049_000019_leftImg8bit.png.jpg'}
# 185 {'height': 512, 'width': 1024, 'id': 185, 'file_name': 'lindau_000006_000019_leftImg8bit.png.jpg'}
# 186 {'height': 512, 'width': 1024, 'id': 186, 'file_name': 'munster_000111_000019_leftImg8bit.png.jpg'}
# 187 {'height': 512, 'width': 1024, 'id': 187, 'file_name': 'munster_000113_000019_leftImg8bit.png.jpg'}
# 188 {'height': 512, 'width': 1024, 'id': 188, 'file_name': 'frankfurt_000000_002963_leftImg8bit.png.jpg'}
# 189 {'height': 512, 'width': 1024, 'id': 189, 'file_name': 'frankfurt_000001_024927_leftImg8bit.png.jpg'}
# 190 {'height': 512, 'width': 1024, 'id': 190, 'file_name': 'frankfurt_000001_001464_leftImg8bit.png.jpg'}
# 191 {'height': 512, 'width': 1024, 'id': 191, 'file_name': 'frankfurt_000001_042733_leftImg8bit.png.jpg'}
# 192 {'height': 512, 'width': 1024, 'id': 192, 'file_name': 'lindau_000054_000019_leftImg8bit.png.jpg'}
# 193 {'height': 512, 'width': 1024, 'id': 193, 'file_name': 'munster_000128_000019_leftImg8bit.png.jpg'}
# 194 {'height': 512, 'width': 1024, 'id': 194, 'file_name': 'frankfurt_000000_013240_leftImg8bit.png.jpg'}
# 195 {'height': 512, 'width': 1024, 'id': 195, 'file_name': 'frankfurt_000001_078803_leftImg8bit.png.jpg'}
# 196 {'height': 512, 'width': 1024, 'id': 196, 'file_name': 'frankfurt_000001_079206_leftImg8bit.png.jpg'}
# 197 {'height': 512, 'width': 1024, 'id': 197, 'file_name': 'frankfurt_000001_007973_leftImg8bit.png.jpg'}
# 198 {'height': 512, 'width': 1024, 'id': 198, 'file_name': 'frankfurt_000001_056580_leftImg8bit.png.jpg'}
# 199 {'height': 512, 'width': 1024, 'id': 199, 'file_name': 'munster_000100_000019_leftImg8bit.png.jpg'}
# 200 {'height': 512, 'width': 1024, 'id': 200, 'file_name': 'frankfurt_000001_029086_leftImg8bit.png.jpg'}
# 201 {'height': 512, 'width': 1024, 'id': 201, 'file_name': 'frankfurt_000001_017459_leftImg8bit.png.jpg'}
# 202 {'height': 512, 'width': 1024, 'id': 202, 'file_name': 'munster_000048_000019_leftImg8bit.png.jpg'}
# 203 {'height': 512, 'width': 1024, 'id': 203, 'file_name': 'frankfurt_000001_052120_leftImg8bit.png.jpg'}
# 204 {'height': 512, 'width': 1024, 'id': 204, 'file_name': 'frankfurt_000001_016273_leftImg8bit.png.jpg'}
# 205 {'height': 512, 'width': 1024, 'id': 205, 'file_name': 'frankfurt_000000_005898_leftImg8bit.png.jpg'}
# 206 {'height': 512, 'width': 1024, 'id': 206, 'file_name': 'lindau_000004_000019_leftImg8bit.png.jpg'}
# 207 {'height': 512, 'width': 1024, 'id': 207, 'file_name': 'lindau_000026_000019_leftImg8bit.png.jpg'}
# 208 {'height': 512, 'width': 1024, 'id': 208, 'file_name': 'munster_000123_000019_leftImg8bit.png.jpg'}
# 209 {'height': 512, 'width': 1024, 'id': 209, 'file_name': 'munster_000034_000019_leftImg8bit.png.jpg'}
# 210 {'height': 512, 'width': 1024, 'id': 210, 'file_name': 'frankfurt_000001_051737_leftImg8bit.png.jpg'}
# 211 {'height': 512, 'width': 1024, 'id': 211, 'file_name': 'frankfurt_000001_025921_leftImg8bit.png.jpg'}
# 212 {'height': 512, 'width': 1024, 'id': 212, 'file_name': 'frankfurt_000001_013496_leftImg8bit.png.jpg'}
# 213 {'height': 512, 'width': 1024, 'id': 213, 'file_name': 'frankfurt_000001_052594_leftImg8bit.png.jpg'}
# 214 {'height': 512, 'width': 1024, 'id': 214, 'file_name': 'munster_000122_000019_leftImg8bit.png.jpg'}
# 215 {'height': 512, 'width': 1024, 'id': 215, 'file_name': 'munster_000116_000019_leftImg8bit.png.jpg'}
# 216 {'height': 512, 'width': 1024, 'id': 216, 'file_name': 'frankfurt_000001_023769_leftImg8bit.png.jpg'}
# 217 {'height': 512, 'width': 1024, 'id': 217, 'file_name': 'munster_000102_000019_leftImg8bit.png.jpg'}
# 218 {'height': 512, 'width': 1024, 'id': 218, 'file_name': 'munster_000009_000019_leftImg8bit.png.jpg'}
# 219 {'height': 512, 'width': 1024, 'id': 219, 'file_name': 'frankfurt_000001_031416_leftImg8bit.png.jpg'}
# 220 {'height': 512, 'width': 1024, 'id': 220, 'file_name': 'munster_000171_000019_leftImg8bit.png.jpg'}
# 221 {'height': 512, 'width': 1024, 'id': 221, 'file_name': 'munster_000032_000019_leftImg8bit.png.jpg'}
# 222 {'height': 512, 'width': 1024, 'id': 222, 'file_name': 'munster_000028_000019_leftImg8bit.png.jpg'}
# 223 {'height': 512, 'width': 1024, 'id': 223, 'file_name': 'lindau_000036_000019_leftImg8bit.png.jpg'}
# 224 {'height': 512, 'width': 1024, 'id': 224, 'file_name': 'munster_000023_000019_leftImg8bit.png.jpg'}
# 225 {'height': 512, 'width': 1024, 'id': 225, 'file_name': 'frankfurt_000000_012009_leftImg8bit.png.jpg'}
# 226 {'height': 512, 'width': 1024, 'id': 226, 'file_name': 'frankfurt_000001_016029_leftImg8bit.png.jpg'}
# 227 {'height': 512, 'width': 1024, 'id': 227, 'file_name': 'lindau_000014_000019_leftImg8bit.png.jpg'}
# 228 {'height': 512, 'width': 1024, 'id': 228, 'file_name': 'munster_000026_000019_leftImg8bit.png.jpg'}
# 229 {'height': 512, 'width': 1024, 'id': 229, 'file_name': 'frankfurt_000000_009969_leftImg8bit.png.jpg'}
# 230 {'height': 512, 'width': 1024, 'id': 230, 'file_name': 'munster_000035_000019_leftImg8bit.png.jpg'}
# 231 {'height': 512, 'width': 1024, 'id': 231, 'file_name': 'munster_000036_000019_leftImg8bit.png.jpg'}
# 232 {'height': 512, 'width': 1024, 'id': 232, 'file_name': 'lindau_000015_000019_leftImg8bit.png.jpg'}
# 233 {'height': 512, 'width': 1024, 'id': 233, 'file_name': 'frankfurt_000001_054077_leftImg8bit.png.jpg'}
# 234 {'height': 512, 'width': 1024, 'id': 234, 'file_name': 'lindau_000047_000019_leftImg8bit.png.jpg'}
# 235 {'height': 512, 'width': 1024, 'id': 235, 'file_name': 'frankfurt_000000_003025_leftImg8bit.png.jpg'}
# 236 {'height': 512, 'width': 1024, 'id': 236, 'file_name': 'frankfurt_000001_054219_leftImg8bit.png.jpg'}
# 237 {'height': 512, 'width': 1024, 'id': 237, 'file_name': 'munster_000013_000019_leftImg8bit.png.jpg'}
# 238 {'height': 512, 'width': 1024, 'id': 238, 'file_name': 'munster_000087_000019_leftImg8bit.png.jpg'}
# 239 {'height': 512, 'width': 1024, 'id': 239, 'file_name': 'munster_000005_000019_leftImg8bit.png.jpg'}
# 240 {'height': 512, 'width': 1024, 'id': 240, 'file_name': 'munster_000173_000019_leftImg8bit.png.jpg'}
# 241 {'height': 512, 'width': 1024, 'id': 241, 'file_name': 'frankfurt_000001_082087_leftImg8bit.png.jpg'}
# 242 {'height': 512, 'width': 1024, 'id': 242, 'file_name': 'frankfurt_000001_039895_leftImg8bit.png.jpg'}
# 243 {'height': 512, 'width': 1024, 'id': 243, 'file_name': 'munster_000163_000019_leftImg8bit.png.jpg'}
# 244 {'height': 512, 'width': 1024, 'id': 244, 'file_name': 'frankfurt_000001_069633_leftImg8bit.png.jpg'}
# 245 {'height': 512, 'width': 1024, 'id': 245, 'file_name': 'munster_000017_000019_leftImg8bit.png.jpg'}
# 246 {'height': 512, 'width': 1024, 'id': 246, 'file_name': 'munster_000031_000019_leftImg8bit.png.jpg'}
# 247 {'height': 512, 'width': 1024, 'id': 247, 'file_name': 'munster_000153_000019_leftImg8bit.png.jpg'}
# 248 {'height': 512, 'width': 1024, 'id': 248, 'file_name': 'munster_000126_000019_leftImg8bit.png.jpg'}
# 249 {'height': 512, 'width': 1024, 'id': 249, 'file_name': 'frankfurt_000001_008688_leftImg8bit.png.jpg'}
# 250 {'height': 512, 'width': 1024, 'id': 250, 'file_name': 'frankfurt_000001_054415_leftImg8bit.png.jpg'}
# 251 {'height': 512, 'width': 1024, 'id': 251, 'file_name': 'frankfurt_000001_073243_leftImg8bit.png.jpg'}
# 252 {'height': 512, 'width': 1024, 'id': 252, 'file_name': 'munster_000062_000019_leftImg8bit.png.jpg'}
# 253 {'height': 512, 'width': 1024, 'id': 253, 'file_name': 'frankfurt_000001_032711_leftImg8bit.png.jpg'}
# 254 {'height': 512, 'width': 1024, 'id': 254, 'file_name': 'frankfurt_000001_057954_leftImg8bit.png.jpg'}
# 255 {'height': 512, 'width': 1024, 'id': 255, 'file_name': 'munster_000099_000019_leftImg8bit.png.jpg'}
# 256 {'height': 512, 'width': 1024, 'id': 256, 'file_name': 'munster_000070_000019_leftImg8bit.png.jpg'}
# 257 {'height': 512, 'width': 1024, 'id': 257, 'file_name': 'frankfurt_000001_042098_leftImg8bit.png.jpg'}
# 258 {'height': 512, 'width': 1024, 'id': 258, 'file_name': 'frankfurt_000001_009854_leftImg8bit.png.jpg'}
# 259 {'height': 512, 'width': 1024, 'id': 259, 'file_name': 'lindau_000017_000019_leftImg8bit.png.jpg'}
# 260 {'height': 512, 'width': 1024, 'id': 260, 'file_name': 'frankfurt_000001_066438_leftImg8bit.png.jpg'}
# 261 {'height': 512, 'width': 1024, 'id': 261, 'file_name': 'frankfurt_000000_020321_leftImg8bit.png.jpg'}
# 262 {'height': 512, 'width': 1024, 'id': 262, 'file_name': 'frankfurt_000001_047552_leftImg8bit.png.jpg'}
# 263 {'height': 512, 'width': 1024, 'id': 263, 'file_name': 'frankfurt_000001_068063_leftImg8bit.png.jpg'}
# 264 {'height': 512, 'width': 1024, 'id': 264, 'file_name': 'frankfurt_000001_047178_leftImg8bit.png.jpg'}
# 265 {'height': 512, 'width': 1024, 'id': 265, 'file_name': 'lindau_000039_000019_leftImg8bit.png.jpg'}
# 266 {'height': 512, 'width': 1024, 'id': 266, 'file_name': 'lindau_000031_000019_leftImg8bit.png.jpg'}
# 267 {'height': 512, 'width': 1024, 'id': 267, 'file_name': 'frankfurt_000000_009688_leftImg8bit.png.jpg'}
# 268 {'height': 512, 'width': 1024, 'id': 268, 'file_name': 'frankfurt_000000_004617_leftImg8bit.png.jpg'}
# 269 {'height': 512, 'width': 1024, 'id': 269, 'file_name': 'frankfurt_000001_010600_leftImg8bit.png.jpg'}
# 270 {'height': 512, 'width': 1024, 'id': 270, 'file_name': 'munster_000121_000019_leftImg8bit.png.jpg'}
# 271 {'height': 512, 'width': 1024, 'id': 271, 'file_name': 'munster_000074_000019_leftImg8bit.png.jpg'}
# 272 {'height': 512, 'width': 1024, 'id': 272, 'file_name': 'frankfurt_000001_062396_leftImg8bit.png.jpg'}
# 273 {'height': 512, 'width': 1024, 'id': 273, 'file_name': 'frankfurt_000000_017476_leftImg8bit.png.jpg'}
# 274 {'height': 512, 'width': 1024, 'id': 274, 'file_name': 'munster_000011_000019_leftImg8bit.png.jpg'}
# 275 {'height': 512, 'width': 1024, 'id': 275, 'file_name': 'frankfurt_000000_012121_leftImg8bit.png.jpg'}
# 276 {'height': 512, 'width': 1024, 'id': 276, 'file_name': 'frankfurt_000001_063045_leftImg8bit.png.jpg'}
# 277 {'height': 512, 'width': 1024, 'id': 277, 'file_name': 'frankfurt_000001_058504_leftImg8bit.png.jpg'}
# 278 {'height': 512, 'width': 1024, 'id': 278, 'file_name': 'frankfurt_000001_030067_leftImg8bit.png.jpg'}
# 279 {'height': 512, 'width': 1024, 'id': 279, 'file_name': 'frankfurt_000001_067092_leftImg8bit.png.jpg'}
# 280 {'height': 512, 'width': 1024, 'id': 280, 'file_name': 'lindau_000048_000019_leftImg8bit.png.jpg'}
# 281 {'height': 512, 'width': 1024, 'id': 281, 'file_name': 'lindau_000038_000019_leftImg8bit.png.jpg'}
# 282 {'height': 512, 'width': 1024, 'id': 282, 'file_name': 'frankfurt_000001_073464_leftImg8bit.png.jpg'}
# 283 {'height': 512, 'width': 1024, 'id': 283, 'file_name': 'munster_000142_000019_leftImg8bit.png.jpg'}
# 284 {'height': 512, 'width': 1024, 'id': 284, 'file_name': 'lindau_000012_000019_leftImg8bit.png.jpg'}
# 285 {'height': 512, 'width': 1024, 'id': 285, 'file_name': 'lindau_000005_000019_leftImg8bit.png.jpg'}
# 286 {'height': 512, 'width': 1024, 'id': 286, 'file_name': 'munster_000138_000019_leftImg8bit.png.jpg'}
# 287 {'height': 512, 'width': 1024, 'id': 287, 'file_name': 'frankfurt_000000_019607_leftImg8bit.png.jpg'}
# 288 {'height': 512, 'width': 1024, 'id': 288, 'file_name': 'frankfurt_000001_055387_leftImg8bit.png.jpg'}
# 289 {'height': 512, 'width': 1024, 'id': 289, 'file_name': 'munster_000039_000019_leftImg8bit.png.jpg'}
# 290 {'height': 512, 'width': 1024, 'id': 290, 'file_name': 'munster_000007_000019_leftImg8bit.png.jpg'}
# 291 {'height': 512, 'width': 1024, 'id': 291, 'file_name': 'munster_000166_000019_leftImg8bit.png.jpg'}
# 292 {'height': 512, 'width': 1024, 'id': 292, 'file_name': 'frankfurt_000001_014406_leftImg8bit.png.jpg'}
# 293 {'height': 512, 'width': 1024, 'id': 293, 'file_name': 'frankfurt_000001_012519_leftImg8bit.png.jpg'}
# 294 {'height': 512, 'width': 1024, 'id': 294, 'file_name': 'frankfurt_000001_077233_leftImg8bit.png.jpg'}
# 295 {'height': 512, 'width': 1024, 'id': 295, 'file_name': 'frankfurt_000001_066832_leftImg8bit.png.jpg'}
# 296 {'height': 512, 'width': 1024, 'id': 296, 'file_name': 'munster_000047_000019_leftImg8bit.png.jpg'}
# 297 {'height': 512, 'width': 1024, 'id': 297, 'file_name': 'frankfurt_000001_054640_leftImg8bit.png.jpg'}
# 298 {'height': 512, 'width': 1024, 'id': 298, 'file_name': 'lindau_000049_000019_leftImg8bit.png.jpg'}
# 299 {'height': 512, 'width': 1024, 'id': 299, 'file_name': 'lindau_000002_000019_leftImg8bit.png.jpg'}
# 300 {'height': 512, 'width': 1024, 'id': 300, 'file_name': 'munster_000063_000019_leftImg8bit.png.jpg'}
# 301 {'height': 512, 'width': 1024, 'id': 301, 'file_name': 'frankfurt_000001_083029_leftImg8bit.png.jpg'}
# 302 {'height': 512, 'width': 1024, 'id': 302, 'file_name': 'frankfurt_000000_000294_leftImg8bit.png.jpg'}
# 303 {'height': 512, 'width': 1024, 'id': 303, 'file_name': 'lindau_000029_000019_leftImg8bit.png.jpg'}
# 304 {'height': 512, 'width': 1024, 'id': 304, 'file_name': 'frankfurt_000001_065617_leftImg8bit.png.jpg'}
# 305 {'height': 512, 'width': 1024, 'id': 305, 'file_name': 'munster_000162_000019_leftImg8bit.png.jpg'}
# 306 {'height': 512, 'width': 1024, 'id': 306, 'file_name': 'frankfurt_000001_049209_leftImg8bit.png.jpg'}
# 307 {'height': 512, 'width': 1024, 'id': 307, 'file_name': 'munster_000057_000019_leftImg8bit.png.jpg'}
# 308 {'height': 512, 'width': 1024, 'id': 308, 'file_name': 'frankfurt_000001_044658_leftImg8bit.png.jpg'}
# 309 {'height': 512, 'width': 1024, 'id': 309, 'file_name': 'munster_000104_000019_leftImg8bit.png.jpg'}
# 310 {'height': 512, 'width': 1024, 'id': 310, 'file_name': 'munster_000159_000019_leftImg8bit.png.jpg'}
# 311 {'height': 512, 'width': 1024, 'id': 311, 'file_name': 'munster_000082_000019_leftImg8bit.png.jpg'}
# 312 {'height': 512, 'width': 1024, 'id': 312, 'file_name': 'frankfurt_000000_014480_leftImg8bit.png.jpg'}
# 313 {'height': 512, 'width': 1024, 'id': 313, 'file_name': 'munster_000000_000019_leftImg8bit.png.jpg'}
# 314 {'height': 512, 'width': 1024, 'id': 314, 'file_name': 'frankfurt_000001_014565_leftImg8bit.png.jpg'}
# 315 {'height': 512, 'width': 1024, 'id': 315, 'file_name': 'munster_000042_000019_leftImg8bit.png.jpg'}
# 316 {'height': 512, 'width': 1024, 'id': 316, 'file_name': 'frankfurt_000001_068208_leftImg8bit.png.jpg'}
# 317 {'height': 512, 'width': 1024, 'id': 317, 'file_name': 'frankfurt_000001_040732_leftImg8bit.png.jpg'}
# 318 {'height': 512, 'width': 1024, 'id': 318, 'file_name': 'frankfurt_000001_007857_leftImg8bit.png.jpg'}
# 319 {'height': 512, 'width': 1024, 'id': 319, 'file_name': 'munster_000045_000019_leftImg8bit.png.jpg'}
# 320 {'height': 512, 'width': 1024, 'id': 320, 'file_name': 'frankfurt_000001_059642_leftImg8bit.png.jpg'}
# 321 {'height': 512, 'width': 1024, 'id': 321, 'file_name': 'frankfurt_000001_071781_leftImg8bit.png.jpg'}
# 322 {'height': 512, 'width': 1024, 'id': 322, 'file_name': 'frankfurt_000001_041354_leftImg8bit.png.jpg'}
# 323 {'height': 512, 'width': 1024, 'id': 323, 'file_name': 'munster_000096_000019_leftImg8bit.png.jpg'}
# 324 {'height': 512, 'width': 1024, 'id': 324, 'file_name': 'frankfurt_000001_012699_leftImg8bit.png.jpg'}
# 325 {'height': 512, 'width': 1024, 'id': 325, 'file_name': 'frankfurt_000001_023235_leftImg8bit.png.jpg'}
# 326 {'height': 512, 'width': 1024, 'id': 326, 'file_name': 'frankfurt_000001_046504_leftImg8bit.png.jpg'}
# 327 {'height': 512, 'width': 1024, 'id': 327, 'file_name': 'munster_000172_000019_leftImg8bit.png.jpg'}
# 328 {'height': 512, 'width': 1024, 'id': 328, 'file_name': 'munster_000144_000019_leftImg8bit.png.jpg'}
# 329 {'height': 512, 'width': 1024, 'id': 329, 'file_name': 'frankfurt_000001_049698_leftImg8bit.png.jpg'}
# 330 {'height': 512, 'width': 1024, 'id': 330, 'file_name': 'munster_000089_000019_leftImg8bit.png.jpg'}
# 331 {'height': 512, 'width': 1024, 'id': 331, 'file_name': 'munster_000132_000019_leftImg8bit.png.jpg'}
# 332 {'height': 512, 'width': 1024, 'id': 332, 'file_name': 'munster_000108_000019_leftImg8bit.png.jpg'}
# 333 {'height': 512, 'width': 1024, 'id': 333, 'file_name': 'lindau_000043_000019_leftImg8bit.png.jpg'}
# 334 {'height': 512, 'width': 1024, 'id': 334, 'file_name': 'frankfurt_000001_062250_leftImg8bit.png.jpg'}
# 335 {'height': 512, 'width': 1024, 'id': 335, 'file_name': 'munster_000084_000019_leftImg8bit.png.jpg'}
# 336 {'height': 512, 'width': 1024, 'id': 336, 'file_name': 'frankfurt_000001_061763_leftImg8bit.png.jpg'}
# 337 {'height': 512, 'width': 1024, 'id': 337, 'file_name': 'munster_000110_000019_leftImg8bit.png.jpg'}
# 338 {'height': 512, 'width': 1024, 'id': 338, 'file_name': 'frankfurt_000001_038418_leftImg8bit.png.jpg'}
# 339 {'height': 512, 'width': 1024, 'id': 339, 'file_name': 'frankfurt_000001_015328_leftImg8bit.png.jpg'}
# 340 {'height': 512, 'width': 1024, 'id': 340, 'file_name': 'frankfurt_000000_010351_leftImg8bit.png.jpg'}
# 341 {'height': 512, 'width': 1024, 'id': 341, 'file_name': 'frankfurt_000001_060545_leftImg8bit.png.jpg'}
# 342 {'height': 512, 'width': 1024, 'id': 342, 'file_name': 'frankfurt_000001_015768_leftImg8bit.png.jpg'}
# 343 {'height': 512, 'width': 1024, 'id': 343, 'file_name': 'munster_000125_000019_leftImg8bit.png.jpg'}
# 344 {'height': 512, 'width': 1024, 'id': 344, 'file_name': 'munster_000068_000019_leftImg8bit.png.jpg'}
# 345 {'height': 512, 'width': 1024, 'id': 345, 'file_name': 'munster_000079_000019_leftImg8bit.png.jpg'}
# 346 {'height': 512, 'width': 1024, 'id': 346, 'file_name': 'lindau_000055_000019_leftImg8bit.png.jpg'}
# 347 {'height': 512, 'width': 1024, 'id': 347, 'file_name': 'lindau_000001_000019_leftImg8bit.png.jpg'}
# 348 {'height': 512, 'width': 1024, 'id': 348, 'file_name': 'frankfurt_000001_062509_leftImg8bit.png.jpg'}
# 349 {'height': 512, 'width': 1024, 'id': 349, 'file_name': 'frankfurt_000001_015091_leftImg8bit.png.jpg'}
# 350 {'height': 512, 'width': 1024, 'id': 350, 'file_name': 'frankfurt_000001_016462_leftImg8bit.png.jpg'}
# 351 {'height': 512, 'width': 1024, 'id': 351, 'file_name': 'munster_000088_000019_leftImg8bit.png.jpg'}
# 352 {'height': 512, 'width': 1024, 'id': 352, 'file_name': 'frankfurt_000001_000538_leftImg8bit.png.jpg'}
# 353 {'height': 512, 'width': 1024, 'id': 353, 'file_name': 'lindau_000025_000019_leftImg8bit.png.jpg'}
# 354 {'height': 512, 'width': 1024, 'id': 354, 'file_name': 'frankfurt_000001_073088_leftImg8bit.png.jpg'}
# 355 {'height': 512, 'width': 1024, 'id': 355, 'file_name': 'frankfurt_000001_010830_leftImg8bit.png.jpg'}
# 356 {'height': 512, 'width': 1024, 'id': 356, 'file_name': 'frankfurt_000001_073911_leftImg8bit.png.jpg'}
# 357 {'height': 512, 'width': 1024, 'id': 357, 'file_name': 'frankfurt_000001_013710_leftImg8bit.png.jpg'}
# 358 {'height': 512, 'width': 1024, 'id': 358, 'file_name': 'frankfurt_000001_013016_leftImg8bit.png.jpg'}
# 359 {'height': 512, 'width': 1024, 'id': 359, 'file_name': 'frankfurt_000001_002646_leftImg8bit.png.jpg'}
# 360 {'height': 512, 'width': 1024, 'id': 360, 'file_name': 'frankfurt_000000_017228_leftImg8bit.png.jpg'}
# 361 {'height': 512, 'width': 1024, 'id': 361, 'file_name': 'lindau_000057_000019_leftImg8bit.png.jpg'}
# 362 {'height': 512, 'width': 1024, 'id': 362, 'file_name': 'frankfurt_000000_012868_leftImg8bit.png.jpg'}
# 363 {'height': 512, 'width': 1024, 'id': 363, 'file_name': 'frankfurt_000001_021406_leftImg8bit.png.jpg'}
# 364 {'height': 512, 'width': 1024, 'id': 364, 'file_name': 'frankfurt_000001_041517_leftImg8bit.png.jpg'}
# 365 {'height': 512, 'width': 1024, 'id': 365, 'file_name': 'frankfurt_000000_016005_leftImg8bit.png.jpg'}
# 366 {'height': 512, 'width': 1024, 'id': 366, 'file_name': 'munster_000052_000019_leftImg8bit.png.jpg'}
# 367 {'height': 512, 'width': 1024, 'id': 367, 'file_name': 'lindau_000051_000019_leftImg8bit.png.jpg'}
# 368 {'height': 512, 'width': 1024, 'id': 368, 'file_name': 'frankfurt_000001_043564_leftImg8bit.png.jpg'}
# 369 {'height': 512, 'width': 1024, 'id': 369, 'file_name': 'frankfurt_000000_003920_leftImg8bit.png.jpg'}
# 370 {'height': 512, 'width': 1024, 'id': 370, 'file_name': 'munster_000037_000019_leftImg8bit.png.jpg'}
# 371 {'height': 512, 'width': 1024, 'id': 371, 'file_name': 'frankfurt_000000_009561_leftImg8bit.png.jpg'}
# 372 {'height': 512, 'width': 1024, 'id': 372, 'file_name': 'lindau_000021_000019_leftImg8bit.png.jpg'}
# 373 {'height': 512, 'width': 1024, 'id': 373, 'file_name': 'munster_000093_000019_leftImg8bit.png.jpg'}
# 374 {'height': 512, 'width': 1024, 'id': 374, 'file_name': 'frankfurt_000001_048355_leftImg8bit.png.jpg'}
# 375 {'height': 512, 'width': 1024, 'id': 375, 'file_name': 'munster_000143_000019_leftImg8bit.png.jpg'}
# 376 {'height': 512, 'width': 1024, 'id': 376, 'file_name': 'frankfurt_000001_046779_leftImg8bit.png.jpg'}
# 377 {'height': 512, 'width': 1024, 'id': 377, 'file_name': 'munster_000109_000019_leftImg8bit.png.jpg'}
# 378 {'height': 512, 'width': 1024, 'id': 378, 'file_name': 'frankfurt_000001_019698_leftImg8bit.png.jpg'}
# 379 {'height': 512, 'width': 1024, 'id': 379, 'file_name': 'frankfurt_000000_016286_leftImg8bit.png.jpg'}
# 380 {'height': 512, 'width': 1024, 'id': 380, 'file_name': 'munster_000169_000019_leftImg8bit.png.jpg'}
# 381 {'height': 512, 'width': 1024, 'id': 381, 'file_name': 'munster_000086_000019_leftImg8bit.png.jpg'}
# 382 {'height': 512, 'width': 1024, 'id': 382, 'file_name': 'munster_000038_000019_leftImg8bit.png.jpg'}
# 383 {'height': 512, 'width': 1024, 'id': 383, 'file_name': 'munster_000157_000019_leftImg8bit.png.jpg'}
# 384 {'height': 512, 'width': 1024, 'id': 384, 'file_name': 'frankfurt_000001_035864_leftImg8bit.png.jpg'}
# 385 {'height': 512, 'width': 1024, 'id': 385, 'file_name': 'frankfurt_000001_011835_leftImg8bit.png.jpg'}
# 386 {'height': 512, 'width': 1024, 'id': 386, 'file_name': 'munster_000092_000019_leftImg8bit.png.jpg'}
# 387 {'height': 512, 'width': 1024, 'id': 387, 'file_name': 'frankfurt_000001_055172_leftImg8bit.png.jpg'}
# 388 {'height': 512, 'width': 1024, 'id': 388, 'file_name': 'frankfurt_000001_038844_leftImg8bit.png.jpg'}
# 389 {'height': 512, 'width': 1024, 'id': 389, 'file_name': 'frankfurt_000001_049298_leftImg8bit.png.jpg'}
# 390 {'height': 512, 'width': 1024, 'id': 390, 'file_name': 'frankfurt_000001_007622_leftImg8bit.png.jpg'}
# 391 {'height': 512, 'width': 1024, 'id': 391, 'file_name': 'frankfurt_000001_048196_leftImg8bit.png.jpg'}
# 392 {'height': 512, 'width': 1024, 'id': 392, 'file_name': 'frankfurt_000001_080830_leftImg8bit.png.jpg'}
# 393 {'height': 512, 'width': 1024, 'id': 393, 'file_name': 'frankfurt_000001_076502_leftImg8bit.png.jpg'}
# 394 {'height': 512, 'width': 1024, 'id': 394, 'file_name': 'frankfurt_000001_064651_leftImg8bit.png.jpg'}
# 395 {'height': 512, 'width': 1024, 'id': 395, 'file_name': 'munster_000077_000019_leftImg8bit.png.jpg'}
# 396 {'height': 512, 'width': 1024, 'id': 396, 'file_name': 'munster_000083_000019_leftImg8bit.png.jpg'}
# 397 {'height': 512, 'width': 1024, 'id': 397, 'file_name': 'frankfurt_000000_020215_leftImg8bit.png.jpg'}
# 398 {'height': 512, 'width': 1024, 'id': 398, 'file_name': 'munster_000076_000019_leftImg8bit.png.jpg'}
# 399 {'height': 512, 'width': 1024, 'id': 399, 'file_name': 'frankfurt_000001_003588_leftImg8bit.png.jpg'}
# 400 {'height': 512, 'width': 1024, 'id': 400, 'file_name': 'munster_000051_000019_leftImg8bit.png.jpg'}
# 401 {'height': 512, 'width': 1024, 'id': 401, 'file_name': 'lindau_000042_000019_leftImg8bit.png.jpg'}
# 402 {'height': 512, 'width': 1024, 'id': 402, 'file_name': 'frankfurt_000001_062653_leftImg8bit.png.jpg'}
# 403 {'height': 512, 'width': 1024, 'id': 403, 'file_name': 'frankfurt_000001_061682_leftImg8bit.png.jpg'}
# 404 {'height': 512, 'width': 1024, 'id': 404, 'file_name': 'frankfurt_000000_015389_leftImg8bit.png.jpg'}
# 405 {'height': 512, 'width': 1024, 'id': 405, 'file_name': 'frankfurt_000001_032556_leftImg8bit.png.jpg'}
# 406 {'height': 512, 'width': 1024, 'id': 406, 'file_name': 'frankfurt_000001_030669_leftImg8bit.png.jpg'}
# 407 {'height': 512, 'width': 1024, 'id': 407, 'file_name': 'munster_000040_000019_leftImg8bit.png.jpg'}
# 408 {'height': 512, 'width': 1024, 'id': 408, 'file_name': 'frankfurt_000001_059119_leftImg8bit.png.jpg'}
# 409 {'height': 512, 'width': 1024, 'id': 409, 'file_name': 'munster_000119_000019_leftImg8bit.png.jpg'}
# 410 {'height': 512, 'width': 1024, 'id': 410, 'file_name': 'lindau_000018_000019_leftImg8bit.png.jpg'}
# 411 {'height': 512, 'width': 1024, 'id': 411, 'file_name': 'lindau_000044_000019_leftImg8bit.png.jpg'}
# 412 {'height': 512, 'width': 1024, 'id': 412, 'file_name': 'munster_000140_000019_leftImg8bit.png.jpg'}
# 413 {'height': 512, 'width': 1024, 'id': 413, 'file_name': 'frankfurt_000001_055062_leftImg8bit.png.jpg'}
# 414 {'height': 512, 'width': 1024, 'id': 414, 'file_name': 'frankfurt_000001_032942_leftImg8bit.png.jpg'}
# 415 {'height': 512, 'width': 1024, 'id': 415, 'file_name': 'frankfurt_000000_011074_leftImg8bit.png.jpg'}
# 416 {'height': 512, 'width': 1024, 'id': 416, 'file_name': 'munster_000133_000019_leftImg8bit.png.jpg'}
# 417 {'height': 512, 'width': 1024, 'id': 417, 'file_name': 'munster_000018_000019_leftImg8bit.png.jpg'}
# 418 {'height': 512, 'width': 1024, 'id': 418, 'file_name': 'munster_000130_000019_leftImg8bit.png.jpg'}
# 419 {'height': 512, 'width': 1024, 'id': 419, 'file_name': 'munster_000097_000019_leftImg8bit.png.jpg'}
# 420 {'height': 512, 'width': 1024, 'id': 420, 'file_name': 'munster_000066_000019_leftImg8bit.png.jpg'}
# 421 {'height': 512, 'width': 1024, 'id': 421, 'file_name': 'frankfurt_000000_001016_leftImg8bit.png.jpg'}
# 422 {'height': 512, 'width': 1024, 'id': 422, 'file_name': 'munster_000065_000019_leftImg8bit.png.jpg'}
# 423 {'height': 512, 'width': 1024, 'id': 423, 'file_name': 'frankfurt_000001_044525_leftImg8bit.png.jpg'}
# 424 {'height': 512, 'width': 1024, 'id': 424, 'file_name': 'frankfurt_000001_050686_leftImg8bit.png.jpg'}
# 425 {'height': 512, 'width': 1024, 'id': 425, 'file_name': 'frankfurt_000000_007365_leftImg8bit.png.jpg'}
# 426 {'height': 512, 'width': 1024, 'id': 426, 'file_name': 'lindau_000016_000019_leftImg8bit.png.jpg'}
# 427 {'height': 512, 'width': 1024, 'id': 427, 'file_name': 'frankfurt_000001_004327_leftImg8bit.png.jpg'}
# 428 {'height': 512, 'width': 1024, 'id': 428, 'file_name': 'frankfurt_000001_034816_leftImg8bit.png.jpg'}
# 429 {'height': 512, 'width': 1024, 'id': 429, 'file_name': 'frankfurt_000001_060906_leftImg8bit.png.jpg'}
# 430 {'height': 512, 'width': 1024, 'id': 430, 'file_name': 'munster_000094_000019_leftImg8bit.png.jpg'}
# 431 {'height': 512, 'width': 1024, 'id': 431, 'file_name': 'frankfurt_000001_043395_leftImg8bit.png.jpg'}
# 432 {'height': 512, 'width': 1024, 'id': 432, 'file_name': 'munster_000150_000019_leftImg8bit.png.jpg'}
# 433 {'height': 512, 'width': 1024, 'id': 433, 'file_name': 'frankfurt_000001_031266_leftImg8bit.png.jpg'}
# 434 {'height': 512, 'width': 1024, 'id': 434, 'file_name': 'munster_000090_000019_leftImg8bit.png.jpg'}
# 435 {'height': 512, 'width': 1024, 'id': 435, 'file_name': 'munster_000044_000019_leftImg8bit.png.jpg'}
# 436 {'height': 512, 'width': 1024, 'id': 436, 'file_name': 'frankfurt_000001_003056_leftImg8bit.png.jpg'}
# 437 {'height': 512, 'width': 1024, 'id': 437, 'file_name': 'frankfurt_000001_017101_leftImg8bit.png.jpg'}
# 438 {'height': 512, 'width': 1024, 'id': 438, 'file_name': 'lindau_000058_000019_leftImg8bit.png.jpg'}
# 439 {'height': 512, 'width': 1024, 'id': 439, 'file_name': 'frankfurt_000001_049770_leftImg8bit.png.jpg'}
# 440 {'height': 512, 'width': 1024, 'id': 440, 'file_name': 'munster_000168_000019_leftImg8bit.png.jpg'}
# 441 {'height': 512, 'width': 1024, 'id': 441, 'file_name': 'munster_000078_000019_leftImg8bit.png.jpg'}
# 442 {'height': 512, 'width': 1024, 'id': 442, 'file_name': 'frankfurt_000001_028335_leftImg8bit.png.jpg'}
# 443 {'height': 512, 'width': 1024, 'id': 443, 'file_name': 'munster_000067_000019_leftImg8bit.png.jpg'}
# 444 {'height': 512, 'width': 1024, 'id': 444, 'file_name': 'frankfurt_000001_055603_leftImg8bit.png.jpg'}
# 445 {'height': 512, 'width': 1024, 'id': 445, 'file_name': 'frankfurt_000000_022254_leftImg8bit.png.jpg'}
# 446 {'height': 512, 'width': 1024, 'id': 446, 'file_name': 'lindau_000050_000019_leftImg8bit.png.jpg'}
# 447 {'height': 512, 'width': 1024, 'id': 447, 'file_name': 'frankfurt_000001_058057_leftImg8bit.png.jpg'}
# 448 {'height': 512, 'width': 1024, 'id': 448, 'file_name': 'frankfurt_000001_034047_leftImg8bit.png.jpg'}
# 449 {'height': 512, 'width': 1024, 'id': 449, 'file_name': 'lindau_000027_000019_leftImg8bit.png.jpg'}
# 450 {'height': 512, 'width': 1024, 'id': 450, 'file_name': 'munster_000025_000019_leftImg8bit.png.jpg'}
# 451 {'height': 512, 'width': 1024, 'id': 451, 'file_name': 'frankfurt_000001_049078_leftImg8bit.png.jpg'}
# 452 {'height': 512, 'width': 1024, 'id': 452, 'file_name': 'frankfurt_000001_040575_leftImg8bit.png.jpg'}
# 453 {'height': 512, 'width': 1024, 'id': 453, 'file_name': 'frankfurt_000000_021879_leftImg8bit.png.jpg'}
# 454 {'height': 512, 'width': 1024, 'id': 454, 'file_name': 'frankfurt_000000_021667_leftImg8bit.png.jpg'}
# 455 {'height': 512, 'width': 1024, 'id': 455, 'file_name': 'frankfurt_000001_057181_leftImg8bit.png.jpg'}
# 456 {'height': 512, 'width': 1024, 'id': 456, 'file_name': 'munster_000146_000019_leftImg8bit.png.jpg'}
# 457 {'height': 512, 'width': 1024, 'id': 457, 'file_name': 'munster_000114_000019_leftImg8bit.png.jpg'}
# 458 {'height': 512, 'width': 1024, 'id': 458, 'file_name': 'frankfurt_000001_055538_leftImg8bit.png.jpg'}
# 459 {'height': 512, 'width': 1024, 'id': 459, 'file_name': 'frankfurt_000001_064130_leftImg8bit.png.jpg'}
# 460 {'height': 512, 'width': 1024, 'id': 460, 'file_name': 'munster_000069_000019_leftImg8bit.png.jpg'}
# 461 {'height': 512, 'width': 1024, 'id': 461, 'file_name': 'lindau_000010_000019_leftImg8bit.png.jpg'}
# 462 {'height': 512, 'width': 1024, 'id': 462, 'file_name': 'munster_000151_000019_leftImg8bit.png.jpg'}
# 463 {'height': 512, 'width': 1024, 'id': 463, 'file_name': 'frankfurt_000001_028854_leftImg8bit.png.jpg'}
# 464 {'height': 512, 'width': 1024, 'id': 464, 'file_name': 'munster_000085_000019_leftImg8bit.png.jpg'}
# 465 {'height': 512, 'width': 1024, 'id': 465, 'file_name': 'frankfurt_000001_062793_leftImg8bit.png.jpg'}
# 466 {'height': 512, 'width': 1024, 'id': 466, 'file_name': 'munster_000103_000019_leftImg8bit.png.jpg'}
# 467 {'height': 512, 'width': 1024, 'id': 467, 'file_name': 'munster_000152_000019_leftImg8bit.png.jpg'}
# 468 {'height': 512, 'width': 1024, 'id': 468, 'file_name': 'munster_000004_000019_leftImg8bit.png.jpg'}
# 469 {'height': 512, 'width': 1024, 'id': 469, 'file_name': 'munster_000022_000019_leftImg8bit.png.jpg'}
# 470 {'height': 512, 'width': 1024, 'id': 470, 'file_name': 'frankfurt_000000_001236_leftImg8bit.png.jpg'}
# 471 {'height': 512, 'width': 1024, 'id': 471, 'file_name': 'lindau_000023_000019_leftImg8bit.png.jpg'}
# 472 {'height': 512, 'width': 1024, 'id': 472, 'file_name': 'frankfurt_000000_022797_leftImg8bit.png.jpg'}
# 473 {'height': 512, 'width': 1024, 'id': 473, 'file_name': 'lindau_000030_000019_leftImg8bit.png.jpg'}
# 474 {'height': 512, 'width': 1024, 'id': 474, 'file_name': 'frankfurt_000001_044227_leftImg8bit.png.jpg'}
# 475 {'height': 512, 'width': 1024, 'id': 475, 'file_name': 'frankfurt_000001_019969_leftImg8bit.png.jpg'}
# 476 {'height': 512, 'width': 1024, 'id': 476, 'file_name': 'munster_000120_000019_leftImg8bit.png.jpg'}
# 477 {'height': 512, 'width': 1024, 'id': 477, 'file_name': 'frankfurt_000001_018113_leftImg8bit.png.jpg'}
# 478 {'height': 512, 'width': 1024, 'id': 478, 'file_name': 'munster_000033_000019_leftImg8bit.png.jpg'}
# 479 {'height': 512, 'width': 1024, 'id': 479, 'file_name': 'munster_000137_000019_leftImg8bit.png.jpg'}
# 480 {'height': 512, 'width': 1024, 'id': 480, 'file_name': 'frankfurt_000000_011810_leftImg8bit.png.jpg'}
# 481 {'height': 512, 'width': 1024, 'id': 481, 'file_name': 'frankfurt_000001_067735_leftImg8bit.png.jpg'}
# 482 {'height': 512, 'width': 1024, 'id': 482, 'file_name': 'frankfurt_000001_046272_leftImg8bit.png.jpg'}
# 483 {'height': 512, 'width': 1024, 'id': 483, 'file_name': 'frankfurt_000001_032018_leftImg8bit.png.jpg'}
# 484 {'height': 512, 'width': 1024, 'id': 484, 'file_name': 'frankfurt_000001_025713_leftImg8bit.png.jpg'}
# 485 {'height': 512, 'width': 1024, 'id': 485, 'file_name': 'munster_000021_000019_leftImg8bit.png.jpg'}
# 486 {'height': 512, 'width': 1024, 'id': 486, 'file_name': 'frankfurt_000000_008206_leftImg8bit.png.jpg'}
# 487 {'height': 512, 'width': 1024, 'id': 487, 'file_name': 'munster_000027_000019_leftImg8bit.png.jpg'}
# 488 {'height': 512, 'width': 1024, 'id': 488, 'file_name': 'frankfurt_000001_062016_leftImg8bit.png.jpg'}
# 489 {'height': 512, 'width': 1024, 'id': 489, 'file_name': 'frankfurt_000001_060422_leftImg8bit.png.jpg'}
# 490 {'height': 512, 'width': 1024, 'id': 490, 'file_name': 'munster_000080_000019_leftImg8bit.png.jpg'}
# 491 {'height': 512, 'width': 1024, 'id': 491, 'file_name': 'frankfurt_000001_072155_leftImg8bit.png.jpg'}
# 492 {'height': 512, 'width': 1024, 'id': 492, 'file_name': 'frankfurt_000001_014221_leftImg8bit.png.jpg'}
# 493 {'height': 512, 'width': 1024, 'id': 493, 'file_name': 'munster_000106_000019_leftImg8bit.png.jpg'}
# 494 {'height': 512, 'width': 1024, 'id': 494, 'file_name': 'lindau_000008_000019_leftImg8bit.png.jpg'}
# 495 {'height': 512, 'width': 1024, 'id': 495, 'file_name': 'frankfurt_000001_080391_leftImg8bit.png.jpg'}
# 496 {'height': 512, 'width': 1024, 'id': 496, 'file_name': 'munster_000112_000019_leftImg8bit.png.jpg'}
# 497 {'height': 512, 'width': 1024, 'id': 497, 'file_name': 'munster_000020_000019_leftImg8bit.png.jpg'}
# 498 {'height': 512, 'width': 1024, 'id': 498, 'file_name': 'frankfurt_000001_058914_leftImg8bit.png.jpg'}
# 499 {'height': 512, 'width': 1024, 'id': 499, 'file_name': 'munster_000101_000019_leftImg8bit.png.jpg'}

# %%
html = coco_dataset.display_image(5, use_url=False)
IPython.display.HTML(html)
# Out:
# Image:
# ======
#   height: 512
#   width: 1024
#   id: 5
#   file_name: munster_000139_000019_leftImg8bit.png.jpg
# /AI/DLDataSet/cityscape/cityscape_labelme/val2017//munster_000139_000019_leftImg8bit.png.jpg
#   segmentations (130):
#     466:blue:{'supercategory': 'sky', 'id': 28, 'name': 'sky'}
#     467:purple:{'supercategory': 'road', 'id': 26, 'name': 'road'}
#     468:red:{'supercategory': 'sidewalk', 'id': 27, 'name': 'sidewalk'}
#     469:green:{'supercategory': 'sidewalk', 'id': 27, 'name': 'sidewalk'}
#     470:orange:{'supercategory': 'building', 'id': 4, 'name': 'building'}
#     471:salmon:{'supercategory': 'person', 'id': 18, 'name': 'person'}
#     472:pink:{'supercategory': 'person', 'id': 18, 'name': 'person'}
#     473:gold:{'supercategory': 'person', 'id': 18, 'name': 'person'}
#     474:orchid:{'supercategory': 'person', 'id': 18, 'name': 'person'}
#     475:slateblue:{'supercategory': 'person', 'id': 18, 'name': 'person'}
#     476:limegreen:{'supercategory': 'person', 'id': 18, 'name': 'person'}
#     477:seagreen:{'supercategory': 'pole', 'id': 20, 'name': 'pole'}
#     478:darkgreen:{'supercategory': 'static', 'id': 29, 'name': 'static'}
#     479:olive:{'supercategory': 'pole', 'id': 20, 'name': 'pole'}
#     480:teal:{'supercategory': 'static', 'id': 29, 'name': 'static'}
#     481:aquamarine:{'supercategory': 'static', 'id': 29, 'name': 'static'}
#     482:steelblue:{'supercategory': 'static', 'id': 29, 'name': 'static'}
#     483:powderblue:{'supercategory': 'dynamic', 'id': 9, 'name': 'dynamic'}
#     484:dodgerblue:{'supercategory': 'person', 'id': 18, 'name': 'person'}
#     485:navy:{'supercategory': 'bicycle', 'id': 1, 'name': 'bicycle'}
#     486:magenta:{'supercategory': 'person', 'id': 18, 'name': 'person'}
#     487:sienna:{'supercategory': 'dynamic', 'id': 9, 'name': 'dynamic'}
#     488:maroon:{'supercategory': 'person', 'id': 18, 'name': 'person'}
#     489:white:{'supercategory': 'pole', 'id': 20, 'name': 'pole'}
#     490:white:{'supercategory': 'traffic sign', 'id': 32, 'name': 'traffic sign'}
#     491:white:{'supercategory': 'dynamic', 'id': 9, 'name': 'dynamic'}
#     492:white:{'supercategory': 'dynamic', 'id': 9, 'name': 'dynamic'}
#     493:white:{'supercategory': 'static', 'id': 29, 'name': 'static'}
#     494:white:{'supercategory': 'static', 'id': 29, 'name': 'static'}
#     495:white:{'supercategory': 'static', 'id': 29, 'name': 'static'}
#     496:white:{'supercategory': 'static', 'id': 29, 'name': 'static'}
#     497:white:{'supercategory': 'static', 'id': 29, 'name': 'static'}
#     498:white:{'supercategory': 'static', 'id': 29, 'name': 'static'}
#     499:white:{'supercategory': 'pole', 'id': 20, 'name': 'pole'}
#     500:white:{'supercategory': 'traffic sign', 'id': 32, 'name': 'traffic sign'}
#     501:white:{'supercategory': 'vegetation', 'id': 36, 'name': 'vegetation'}
#     502:white:{'supercategory': 'static', 'id': 29, 'name': 'static'}
#     503:white:{'supercategory': 'building', 'id': 4, 'name': 'building'}
#     504:white:{'supercategory': 'person', 'id': 18, 'name': 'person'}
#     505:white:{'supercategory': 'person', 'id': 18, 'name': 'person'}
#     506:white:{'supercategory': 'static', 'id': 29, 'name': 'static'}
#     507:white:{'supercategory': 'person', 'id': 18, 'name': 'person'}
#     508:white:{'supercategory': 'pole', 'id': 20, 'name': 'pole'}
#     509:white:{'supercategory': 'traffic sign', 'id': 32, 'name': 'traffic sign'}
#     510:white:{'supercategory': 'traffic sign', 'id': 32, 'name': 'traffic sign'}
#     511:white:{'supercategory': 'traffic sign', 'id': 32, 'name': 'traffic sign'}
#     512:white:{'supercategory': 'traffic sign', 'id': 32, 'name': 'traffic sign'}
#     513:white:{'supercategory': 'static', 'id': 29, 'name': 'static'}
#     514:white:{'supercategory': 'static', 'id': 29, 'name': 'static'}
#     515:white:{'supercategory': 'person', 'id': 18, 'name': 'person'}
#     516:white:{'supercategory': 'person', 'id': 18, 'name': 'person'}
#     517:white:{'supercategory': 'pole', 'id': 20, 'name': 'pole'}
#     518:white:{'supercategory': 'traffic sign', 'id': 32, 'name': 'traffic sign'}
#     519:white:{'supercategory': 'static', 'id': 29, 'name': 'static'}
#     520:white:{'supercategory': 'static', 'id': 29, 'name': 'static'}
#     521:white:{'supercategory': 'static', 'id': 29, 'name': 'static'}
#     522:white:{'supercategory': 'static', 'id': 29, 'name': 'static'}
#     523:white:{'supercategory': 'static', 'id': 29, 'name': 'static'}
#     524:white:{'supercategory': 'static', 'id': 29, 'name': 'static'}
#     525:white:{'supercategory': 'static', 'id': 29, 'name': 'static'}
#     526:white:{'supercategory': 'static', 'id': 29, 'name': 'static'}
#     527:white:{'supercategory': 'static', 'id': 29, 'name': 'static'}
#     528:white:{'supercategory': 'static', 'id': 29, 'name': 'static'}
#     529:white:{'supercategory': 'static', 'id': 29, 'name': 'static'}
#     530:white:{'supercategory': 'static', 'id': 29, 'name': 'static'}
#     531:white:{'supercategory': 'static', 'id': 29, 'name': 'static'}
#     532:white:{'supercategory': 'static', 'id': 29, 'name': 'static'}
#     533:white:{'supercategory': 'static', 'id': 29, 'name': 'static'}
#     534:white:{'supercategory': 'bicycle', 'id': 1, 'name': 'bicycle'}
#     535:white:{'supercategory': 'pole', 'id': 20, 'name': 'pole'}
#     536:white:{'supercategory': 'traffic sign', 'id': 32, 'name': 'traffic sign'}
#     537:white:{'supercategory': 'person', 'id': 18, 'name': 'person'}
#     538:white:{'supercategory': 'person', 'id': 18, 'name': 'person'}
#     539:white:{'supercategory': 'person', 'id': 18, 'name': 'person'}
#     540:white:{'supercategory': 'person', 'id': 18, 'name': 'person'}
#     541:white:{'supercategory': 'pole', 'id': 20, 'name': 'pole'}
#     542:white:{'supercategory': 'traffic sign', 'id': 32, 'name': 'traffic sign'}
#     543:white:{'supercategory': 'person', 'id': 18, 'name': 'person'}
#     544:white:{'supercategory': 'person', 'id': 18, 'name': 'person'}
#     545:white:{'supercategory': 'person', 'id': 18, 'name': 'person'}
#     546:white:{'supercategory': 'person', 'id': 18, 'name': 'person'}
#     547:white:{'supercategory': 'person', 'id': 18, 'name': 'person'}
#     548:white:{'supercategory': 'person', 'id': 18, 'name': 'person'}
#     549:white:{'supercategory': 'static', 'id': 29, 'name': 'static'}
#     550:white:{'supercategory': 'static', 'id': 29, 'name': 'static'}
#     551:white:{'supercategory': 'static', 'id': 29, 'name': 'static'}
#     552:white:{'supercategory': 'static', 'id': 29, 'name': 'static'}
#     553:white:{'supercategory': 'static', 'id': 29, 'name': 'static'}
#     554:white:{'supercategory': 'static', 'id': 29, 'name': 'static'}
#     555:white:{'supercategory': 'static', 'id': 29, 'name': 'static'}
#     556:white:{'supercategory': 'static', 'id': 29, 'name': 'static'}
#     557:white:{'supercategory': 'static', 'id': 29, 'name': 'static'}
#     558:white:{'supercategory': 'static', 'id': 29, 'name': 'static'}
#     559:white:{'supercategory': 'static', 'id': 29, 'name': 'static'}
#     560:white:{'supercategory': 'static', 'id': 29, 'name': 'static'}
#     561:white:{'supercategory': 'static', 'id': 29, 'name': 'static'}
#     562:white:{'supercategory': 'static', 'id': 29, 'name': 'static'}
#     563:white:{'supercategory': 'static', 'id': 29, 'name': 'static'}
#     564:white:{'supercategory': 'static', 'id': 29, 'name': 'static'}
#     565:white:{'supercategory': 'static', 'id': 29, 'name': 'static'}
#     566:white:{'supercategory': 'static', 'id': 29, 'name': 'static'}
#     567:white:{'supercategory': 'license plate', 'id': 14, 'name': 'license plate'}
#     568:white:{'supercategory': 'bicycle', 'id': 1, 'name': 'bicycle'}
#     569:white:{'supercategory': 'rider', 'id': 24, 'name': 'rider'}
#     570:white:{'supercategory': 'bicycle', 'id': 1, 'name': 'bicycle'}
#     571:white:{'supercategory': 'rider', 'id': 24, 'name': 'rider'}
#     572:white:{'supercategory': 'bicycle', 'id': 1, 'name': 'bicycle'}
#     573:white:{'supercategory': 'rider', 'id': 24, 'name': 'rider'}
#     574:white:{'supercategory': 'bicycle', 'id': 1, 'name': 'bicycle'}
#     575:white:{'supercategory': 'rider', 'id': 24, 'name': 'rider'}
#     576:white:{'supercategory': 'bicycle', 'id': 1, 'name': 'bicycle'}
#     577:white:{'supercategory': 'bicyclegroup', 'id': 2, 'name': 'bicyclegroup'}
#     578:white:{'supercategory': 'bicyclegroup', 'id': 2, 'name': 'bicyclegroup'}
#     579:white:{'supercategory': 'car', 'id': 6, 'name': 'car'}
#     580:white:{'supercategory': 'bicyclegroup', 'id': 2, 'name': 'bicyclegroup'}
#     581:white:{'supercategory': 'bicyclegroup', 'id': 2, 'name': 'bicyclegroup'}
#     582:white:{'supercategory': 'bicyclegroup', 'id': 2, 'name': 'bicyclegroup'}
#     583:white:{'supercategory': 'bicyclegroup', 'id': 2, 'name': 'bicyclegroup'}
#     584:white:{'supercategory': 'bicyclegroup', 'id': 2, 'name': 'bicyclegroup'}
#     585:white:{'supercategory': 'bicycle', 'id': 1, 'name': 'bicycle'}
#     586:white:{'supercategory': 'bicycle', 'id': 1, 'name': 'bicycle'}
#     587:white:{'supercategory': 'bicycle', 'id': 1, 'name': 'bicycle'}
#     588:white:{'supercategory': 'bicycle', 'id': 1, 'name': 'bicycle'}
#     589:white:{'supercategory': 'bicycle', 'id': 1, 'name': 'bicycle'}
#     590:white:{'supercategory': 'bicycle', 'id': 1, 'name': 'bicycle'}
#     591:white:{'supercategory': 'bicycle', 'id': 1, 'name': 'bicycle'}
#     592:white:{'supercategory': 'bicycle', 'id': 1, 'name': 'bicycle'}
#     593:white:{'supercategory': 'bicycle', 'id': 1, 'name': 'bicycle'}
#     594:white:{'supercategory': 'ego vehicle', 'id': 10, 'name': 'ego vehicle'}
#     595:white:{'supercategory': 'out of roi', 'id': 16, 'name': 'out of roi'}
# <div class="container" style="position:relative;"><img src="/AI/DLDataSet/cityscape/cityscape_labelme/val2017//munster_000139_000019_leftImg8bit.png.jpg" style="position:relative;top:0px;left:0px;width:600px;"><div class="svgclass"><svg width="600" height="300.0"><polygon points="176   0 282   0 276  55 185  52" style="fill:blue; stroke:blue; stroke-width:1; fill-opacity:0.5" /><polygon points="223 127 266 127 599 267 600 299   0 300   0 206" style="fill:purple; stroke:purple; stroke-width:1; fill-opacity:0.5" /><polygon points="  0 158 223 121 227 128 222 131 211 134 195 138 185 143 174 150 159 158
#  145 165 125 174  99 182  75 191  45 202  18 212   7 216   0 219" style="fill:red; stroke:red; stroke-width:1; fill-opacity:0.5" /><polygon points="273 123 366 133 511 148 600 157 599 290 435 212 328 162" style="fill:green; stroke:green; stroke-width:1; fill-opacity:0.5" /><polygon points="  0   0 183   0 193  21 215  21 215   8 216   4 216   5 217   9 219  14
#  219  15 220  22 221  29 220  36 262  29 261  17 260  15 261   9 260   9
#  256   8 256   7 261   7 263   2 261   0 379   0 382 147 264 128 254 128
#  237 127 225 128 219 130 205 130 193 131 192 134 185 134 174 136 145 141
#  136 144 130 144 120 146 110 147 101 150  97 150  90 151  86 152  61 155
#   42 158  19 162   0 166" style="fill:orange; stroke:orange; stroke-width:1; fill-opacity:0.5" /><polygon points="210 123 212 122 212 121 213 120 214 120 216 121 216 124 215 127 215 129
#  214 130 212 130 211 128 210 125" style="fill:salmon; stroke:salmon; stroke-width:1; fill-opacity:0.5" /><polygon points="216 120 217 121 218 123 218 128 216 128 215 127 215 124 216 121 216 121" style="fill:pink; stroke:pink; stroke-width:1; fill-opacity:0.5" /><polygon points="226 122 227 121 227 120 228 120 229 119 230 118 231 119 232 120 232 128
#  230 128 229 128 227 127 227 124" style="fill:gold; stroke:gold; stroke-width:1; fill-opacity:0.5" /><polygon points="225 125 224 123 225 122 225 121 225 121 226 121 226 121 226 122 227 124
#  227 127 227 128 225 128 225 127 225 126" style="fill:orchid; stroke:orchid; stroke-width:1; fill-opacity:0.5" /><polygon points="232 119 233 121 233 124 233 130 232 130 232 130 230 129 230 125 230 124
#  231 121 231 120" style="fill:slateblue; stroke:slateblue; stroke-width:1; fill-opacity:0.5" /><polygon points="234 121 234 120 235 119 236 120 236 121 236 121 237 123 237 128 236 130
#  235 130 234 131 233 130 233 129 233 126 233 125 233 124 233 122 233 121" style="fill:limegreen; stroke:limegreen; stroke-width:1; fill-opacity:0.5" /><polygon points="241 115 241 119 241 120 241 114" style="fill:seagreen; stroke:seagreen; stroke-width:1; fill-opacity:0.5" /><polygon points="241 114 241 114 242 115 243 116 241 117 241 117 240 117 240 116 240 114
#  240 114" style="fill:darkgreen; stroke:darkgreen; stroke-width:1; fill-opacity:0.5" /><polygon points="253 114 253 124 254 125 253 113" style="fill:olive; stroke:olive; stroke-width:1; fill-opacity:0.5" /><polygon points="254 111 254 115 252 115 252 111" style="fill:teal; stroke:teal; stroke-width:1; fill-opacity:0.5" /><polygon points="239 128 239 133 239 133 239 128" style="fill:aquamarine; stroke:aquamarine; stroke-width:1; fill-opacity:0.5" /><polygon points="238 127 237 125 236 124 236 122 237 120 238 120 238 119 239 118 240 118
#  241 119 241 122 241 127 240 131 239 131 237 131 237 129 237 128" style="fill:steelblue; stroke:steelblue; stroke-width:1; fill-opacity:0.5" /><polygon points="243 122 244 120 246 119 247 118 247 117 247 117 249 118 249 118 252 120
#  254 127 248 128 244 127 243 125 243 124" style="fill:powderblue; stroke:powderblue; stroke-width:1; fill-opacity:0.5" /><polygon points="247 122 249 121 250 120 250 120 250 118 250 117 251 117 252 118 253 121
#  254 124 254 127 254 129 254 130 253 129 252 131 251 130 250 128 250 126
#  250 124 250 123 247 123 246 123" style="fill:dodgerblue; stroke:dodgerblue; stroke-width:1; fill-opacity:0.5" /><polygon points="247 131 246 130 246 128 246 125 246 124 246 123 248 123 248 124 248 124
#  250 124 251 125 253 127 252 130 250 131 250 131 249 128 248 128 248 129
#  247 130" style="fill:navy; stroke:navy; stroke-width:1; fill-opacity:0.5" /><polygon points="254 121 255 120 256 118 257 119 258 122 257 127 255 130 254 129 254 124
#  254 122" style="fill:magenta; stroke:magenta; stroke-width:1; fill-opacity:0.5" /><polygon points="256 122 261 123 258 126 256 125 255 125" style="fill:sienna; stroke:sienna; stroke-width:1; fill-opacity:0.5" /><polygon points="260 125 259 124 260 123 260 121 260 121 260 120 260 118 261 118 261 117
#  262 118 262 120 263 121 264 123 263 125 261 125" style="fill:maroon; stroke:maroon; stroke-width:1; fill-opacity:0.5" /><polygon points="263 110 263 131 264 131 264 108" style="fill:white; stroke:white; stroke-width:1; fill-opacity:0.5" /><polygon points="263 102 264 103 269 109 269 111 260 111 259 111 263 103" style="fill:white; stroke:white; stroke-width:1; fill-opacity:0.5" /><polygon points="256 130 256 128 257 127 257 125 259 124 261 123 263 123 264 122 265 121
#  267 121 261 135 257 134 256 132" style="fill:white; stroke:white; stroke-width:1; fill-opacity:0.5" /><polygon points="254 132 258 134 258 136 257 137 257 138 255 138 254 135 254 133" style="fill:white; stroke:white; stroke-width:1; fill-opacity:0.5" /><polygon points="269  94 277  94 277  97 269  98" style="fill:white; stroke:white; stroke-width:1; fill-opacity:0.5" /><polygon points="280  97 280 104 272 103 272  97" style="fill:white; stroke:white; stroke-width:1; fill-opacity:0.5" /><polygon points="300  85 312  86 311  91 300  91" style="fill:white; stroke:white; stroke-width:1; fill-opacity:0.5" /><polygon points="320  82 322  80 326  80 329  80 332  81 332  86 320  86" style="fill:white; stroke:white; stroke-width:1; fill-opacity:0.5" /><polygon points="299  93 309  93 309  97 299  97" style="fill:white; stroke:white; stroke-width:1; fill-opacity:0.5" /><polygon points="288  90 292  90 294  91 296  94 296  97 295 100 285 100 283  96 284  92" style="fill:white; stroke:white; stroke-width:1; fill-opacity:0.5" /><polygon points="286  84 287 115 288 115 287  83" style="fill:white; stroke:white; stroke-width:1; fill-opacity:0.5" /><polygon points="288  91 289  91 290  93 290  96 289  97 287  99 284  97 283  96 283  92
#  284  91" style="fill:white; stroke:white; stroke-width:1; fill-opacity:0.5" /><polygon points="341  79 342  76 345  73 348  71 352  70 355  70 356 104 350 107 342 106
#  339 103 341  99 341  94 339  92 338  94 336  92 338  89 340  86 339  84
#  339  82" style="fill:white; stroke:white; stroke-width:1; fill-opacity:0.5" /><polygon points="345 104 355 104 355 127 346 125" style="fill:white; stroke:white; stroke-width:1; fill-opacity:0.5" /><polygon points="353   0 599   0 600 164 355 133" style="fill:white; stroke:white; stroke-width:1; fill-opacity:0.5" /><polygon points="326 127 327 124 326 120 327 117 328 117 329 114 329 113 331 113 332 115
#  332 117 334 118 335 124 335 128" style="fill:white; stroke:white; stroke-width:1; fill-opacity:0.5" /><polygon points="336 125 337 120 338 118 340 116 342 113 342 111 345 111 346 113 346 116
#  348 118 348 126 345 127 338 127" style="fill:white; stroke:white; stroke-width:1; fill-opacity:0.5" /><polygon points="391  74 404  75 405  81 391  81" style="fill:white; stroke:white; stroke-width:1; fill-opacity:0.5" /><polygon points="400 114 403 112 403 110 403 107 406 106 407 107 408 110 408 113 411 113
#  412 116 413 119 415 121 416 123 414 124 411 124 410 135 402 134 400 127
#  399 124 397 121 398 117 399 115" style="fill:white; stroke:white; stroke-width:1; fill-opacity:0.5" /><polygon points="409  39 410 137 412 139 411  39" style="fill:white; stroke:white; stroke-width:1; fill-opacity:0.5" /><polygon points="417  80 417  87 404  87 404  80" style="fill:white; stroke:white; stroke-width:1; fill-opacity:0.5" /><polygon points="417  72 417  80 404  80 404  73" style="fill:white; stroke:white; stroke-width:1; fill-opacity:0.5" /><polygon points="413  59 415  60 417  63 417  67 417  70 414  72 41

# %%
html = coco_dataset.display_image(1, use_url=False)
IPython.display.HTML(html)
# Out:
# Image:
# ======
#   height: 512
#   width: 1024
#   id: 1
#   file_name: frankfurt_000001_035144_leftImg8bit.png.jpg
# /AI/DLDataSet/cityscape/cityscape_labelme/val2017//frankfurt_000001_035144_leftImg8bit.png.jpg
#   segmentations (114):
#     98:blue:{'supercategory': 'building', 'id': 4, 'name': 'building'}
#     99:purple:{'supercategory': 'road', 'id': 26, 'name': 'road'}
#     100:red:{'supercategory': 'sidewalk', 'id': 27, 'name': 'sidewalk'}
#     101:green:{'supercategory': 'sky', 'id': 28, 'name': 'sky'}
#     102:orange:{'supercategory': 'ground', 'id': 12, 'name': 'ground'}
#     103:salmon:{'supercategory': 'sidewalk', 'id': 27, 'name': 'sidewalk'}
#     104:pink:{'supercategory': 'building', 'id': 4, 'name': 'building'}
#     105:gold:{'supercategory': 'vegetation', 'id': 36, 'name': 'vegetation'}
#     106:orchid:{'supercategory': 'building', 'id': 4, 'name': 'building'}
#     107:slateblue:{'supercategory': 'pole', 'id': 20, 'name': 'pole'}
#     108:limegreen:{'supercategory': 'static', 'id': 29, 'name': 'static'}
#     109:seagreen:{'supercategory': 'pole', 'id': 20, 'name': 'pole'}
#     110:darkgreen:{'supercategory': 'person', 'id': 18, 'name': 'person'}
#     111:olive:{'supercategory': 'fence', 'id': 11, 'name': 'fence'}
#     112:teal:{'supercategory': 'pole', 'id': 20, 'name': 'pole'}
#     113:aquamarine:{'supercategory': 'traffic light', 'id': 31, 'name': 'traffic light'}
#     114:steelblue:{'supercategory': 'traffic sign', 'id': 32, 'name': 'traffic sign'}
#     115:powderblue:{'supercategory': 'vegetation', 'id': 36, 'name': 'vegetation'}
#     116:dodgerblue:{'supercategory': 'pole', 'id': 20, 'name': 'pole'}
#     117:navy:{'supercategory': 'traffic sign', 'id': 32, 'name': 'traffic sign'}
#     118:magenta:{'supercategory': 'static', 'id': 29, 'name': 'static'}
#     119:sienna:{'supercategory': 'wall', 'id': 37, 'name': 'wall'}
#     120:maroon:{'supercategory': 'fence', 'id': 11, 'name': 'fence'}
#     121:white:{'supercategory': 'pole', 'id': 20, 'name': 'pole'}
#     122:white:{'supercategory': 'traffic sign', 'id': 32, 'name': 'traffic sign'}
#     123:white:{'supercategory': 'traffic sign', 'id': 32, 'name': 'traffic sign'}
#     124:white:{'supercategory': 'pole', 'id': 20, 'name': 'pole'}
#     125:white:{'supercategory': 'pole', 'id': 20, 'name': 'pole'}
#     126:white:{'supercategory': 'traffic sign', 'id': 32, 'name': 'traffic sign'}
#     127:white:{'supercategory': 'traffic light', 'id': 31, 'name': 'traffic light'}
#     128:white:{'supercategory': 'traffic light', 'id': 31, 'name': 'traffic light'}
#     129:white:{'supercategory': 'car', 'id': 6, 'name': 'car'}
#     130:white:{'supercategory': 'pole', 'id': 20, 'name': 'pole'}
#     131:white:{'supercategory': 'traffic sign', 'id': 32, 'name': 'traffic sign'}
#     132:white:{'supercategory': 'pole', 'id': 20, 'name': 'pole'}
#     133:white:{'supercategory': 'car', 'id': 6, 'name': 'car'}
#     134:white:{'supercategory': 'car', 'id': 6, 'name': 'car'}
#     135:white:{'supercategory': 'car', 'id': 6, 'name': 'car'}
#     136:white:{'supercategory': 'car', 'id': 6, 'name': 'car'}
#     137:white:{'supercategory': 'car', 'id': 6, 'name': 'car'}
#     138:white:{'supercategory': 'car', 'id': 6, 'name': 'car'}
#     139:white:{'supercategory': 'car', 'id': 6, 'name': 'car'}
#     140:white:{'supercategory': 'car', 'id': 6, 'name': 'car'}
#     141:white:{'supercategory': 'pole', 'id': 20, 'name': 'pole'}
#     142:white:{'supercategory': 'traffic sign', 'id': 32, 'name': 'traffic sign'}
#     143:white:{'supercategory': 'pole', 'id': 20, 'name': 'pole'}
#     144:white:{'supercategory': 'traffic sign', 'id': 32, 'name': 'traffic sign'}
#     145:white:{'supercategory': 'static', 'id': 29, 'name': 'static'}
#     146:white:{'supercategory': 'car', 'id': 6, 'name': 'car'}
#     147:white:{'supercategory': 'pole', 'id': 20, 'name': 'pole'}
#     148:white:{'supercategory': 'pole', 'id': 20, 'name': 'pole'}
#     149:white:{'supercategory': 'pole', 'id': 20, 'name': 'pole'}
#     150:white:{'supercategory': 'pole', 'id': 20, 'name': 'pole'}
#     151:white:{'supercategory': 'traffic sign', 'id': 32, 'name': 'traffic sign'}
#     152:white:{'supercategory': 'traffic light', 'id': 31, 'name': 'traffic light'}
#     153:white:{'supercategory': 'traffic sign', 'id': 32, 'name': 'traffic sign'}
#     154:white:{'supercategory': 'traffic sign', 'id': 32, 'name': 'traffic sign'}
#     155:white:{'supercategory': 'pole', 'id': 20, 'name': 'pole'}
#     156:white:{'supercategory': 'traffic sign', 'id': 32, 'name': 'traffic sign'}
#     157:white:{'supercategory': 'pole', 'id': 20, 'name': 'pole'}
#     158:white:{'supercategory': 'dynamic', 'id': 9, 'name': 'dynamic'}
#     159:white:{'supercategory': 'static', 'id': 29, 'name': 'static'}
#     160:white:{'supercategory': 'motorcycle', 'id': 15, 'name': 'motorcycle'}
#     161:white:{'supercategory': 'bicycle', 'id': 1, 'name': 'bicycle'}
#     162:white:{'supercategory': 'vegetation', 'id': 36, 'name': 'vegetation'}
#     163:white:{'supercategory': 'vegetation', 'id': 36, 'name': 'vegetation'}
#     164:white:{'supercategory': 'traffic sign', 'id': 32, 'name': 'traffic sign'}
#     165:white:{'supercategory': 'traffic sign', 'id': 32, 'name': 'traffic sign'}
#     166:white:{'supercategory': 'traffic sign', 'id': 32, 'name': 'traffic sign'}
#     167:white:{'supercategory': 'static', 'id': 29, 'name': 'static'}
#     168:white:{'supercategory': 'car', 'id': 6, 'name': 'car'}
#     169:white:{'supercategory': 'license plate', 'id': 14, 'name': 'license plate'}
#     170:white:{'supercategory': 'car', 'id': 6, 'name': 'car'}
#     171:white:{'supercategory': 'license plate', 'id': 14, 'name': 'license plate'}
#     172:white:{'supercategory': 'car', 'id': 6, 'name': 'car'}
#     173:white:{'supercategory': 'car', 'id': 6, 'name': 'car'}
#     174:white:{'supercategory': 'car', 'id': 6, 'name': 'car'}
#     175:white:{'supercategory': 'car', 'id': 6, 'name': 'car'}
#     176:white:{'supercategory': 'person', 'id': 18, 'name': 'person'}
#     177:white:{'supercategory': 'person', 'id': 18, 'name': 'person'}
#     178:white:{'supercategory': 'person', 'id': 18, 'name': 'person'}
#     179:white:{'supercategory': 'license plate', 'id': 14, 'name': 'license plate'}
#     180:white:{'supercategory': 'person', 'id': 18, 'name': 'person'}
#     181:white:{'supercategory': 'person', 'id': 18, 'name': 'person'}
#     182:white:{'supercategory': 'pole', 'id': 20, 'name': 'pole'}
#     183:white:{'supercategory': 'traffic light', 'id': 31, 'name': 'traffic light'}
#     184:white:{'supercategory': 'pole', 'id': 20, 'name': 'pole'}
#     185:white:{'supercategory': 'car', 'id': 6, 'name': 'car'}
#     186:white:{'supercategory': 'car', 'id': 6, 'name': 'car'}
#     187:white:{'supercategory': 'car', 'id': 6, 'name': 'car'}
#     188:white:{'supercategory': 'car', 'id': 6, 'name': 'car'}
#     189:white:{'supercategory': 'car', 'id': 6, 'name': 'car'}
#     190:white:{'supercategory': 'car', 'id': 6, 'name': 'car'}
#     191:white:{'supercategory': 'car', 'id': 6, 'name': 'car'}
#     192:white:{'supercategory': 'car', 'id': 6, 'name': 'car'}
#     193:white:{'supercategory': 'car', 'id': 6, 'name': 'car'}
#     194:white:{'supercategory': 'car', 'id': 6, 'name': 'car'}
#     195:white:{'supercategory': 'car', 'id': 6, 'name': 'car'}
#     196:white:{'supercategory': 'pole', 'id': 20, 'name': 'pole'}
#     197:white:{'supercategory': 'traffic sign', 'id': 32, 'name': 'traffic sign'}
#     198:white:{'supercategory': 'car', 'id': 6, 'name': 'car'}
#     199:white:{'supercategory': 'car', 'id': 6, 'name': 'car'}
#     200:white:{'supercategory': 'license plate', 'id': 14, 'name': 'license plate'}
#     201:white:{'supercategory': 'pole', 'id': 20, 'name': 'pole'}
#     202:white:{'supercategory': 'traffic sign', 'id': 32, 'name': 'traffic sign'}
#     203:white:{'supercategory': 'traffic sign', 'id': 32, 'name': 'traffic sign'}
#     204:white:{'supercategory': 'static', 'id': 29, 'name': 'static'}
#     205:white:{'supercategory': 'static', 'id': 29, 'name': 'static'}
#     206:white:{'supercategory': 'ego vehicle', 'id': 10, 'name': 'ego vehicle'}
#     207:white:{'supercategory': 'rectification border', 'id': 23, 'name': 'rectification border'}
#     208:white:{'supercategory': 'rectification border', 'id': 23, 'name': 'rectification border'}
#     209:white:{'supercategory': 'rectification border', 'id': 23, 'name': 'rectification border'}
#     210:white:{'supercategory': 'rectification border', 'id': 23, 'name': 'rectification border'}
#     211:white:{'supercategory': 'out of roi', 'id': 16, 'name': 'out of roi'}
# <div class="container" style="position:relative;"><img src="/AI/DLDataSet/cityscape/cityscape_labelme/val2017//frankfurt_000001_035144_leftImg8bit.png.jpg" style="position:relative;top:0px;left:0px;width:600px;"><div class="svgclass"><svg width="600" height="300.0"><polygon points="325 100 326 124 346 128 348 121 346 106 347 101 345  96 339  96 331  99" style="fill:blue; stroke:blue; stroke-width:1; fill-opacity:0.5" /><polygon points="599 216 599 157 335 124 257  95   0 118   0 299 599 299" style="fill:purple; stroke:purple; stroke-width:1; fill-opacity:0.5" /><polygon points="409 149 408 154 389 154 372 148 339 141 333 140 333 139 340 137 357 137
#  361 136 360 134 355 134 346 134 342 134 337 134 335 133 335 132 331 132
#  320 127 315 121 335 121 364 121 391 118 406 121 412 125 419 133 418 140" style="fill:red; stroke:red; stroke-width:1; fill-opacity:0.5" /><polygon points="158   0 163  26 205  68 232  84 253  88 262  84 272  75 278  64 292  52
#  302  40 313  28 319  13 320   0" style="fill:green; stroke:green; stroke-width:1; fill-opacity:0.5" /><polygon points="116 288 137 273 241 190 263 169 269 161 271 152 270 148 268 145 263 139
#  261 137 258 137 241 137 225 147 208 157 200 161   0 229   0 299 104 299" style="fill:orange; stroke:orange; stroke-width:1; fill-opacity:0.5" /><polygon points="203 159 203 159 205 182 225 181 246 180 247 184 263 169 269 161 271 152
#  270 148 268 145 263 139 261 137 258 137 241 137 225 147 208 157 203 159" style="fill:salmon; stroke:salmon; stroke-width:1; fill-opacity:0.5" /><polygon points="297  92 274  83 257  77 256  77 254  74 249  74 248  60 246  58 234  58
#  234  49 229  45 229  43 229  39 225  33 225  29 223  29 223  29 223  32
#  219  32 219  29 220  28 220  23 220  22 217  22 217  32 217  32 213  32
#  212  32 212  25 203  16 194  16 191  14 190  14 188  13 186  11 184  10
#  183   9 179   9 156  10 154   0   0   0   0 135 139 127 179 126 192 125
#  195 127 214 126 233 121 240 121 252 118 270 121 284 122 292 121 295 121
#  298 108 297 101 295  90" style="fill:pink; stroke:pink; stroke-width:1; fill-opacity:0.5" /><polygon points="313   7 307   5 305   9 304  11 304  14 304  15 304  18 304  19 304  20
#  302  22 302  24 302  26 300  26 300  26 297  25 295  24 297  23 298  22
#  298  22 297  21 295  22 293  20 292  19 292  18 292  16 291  16 289  18
#  288  16 287  15 284  15 283  15 281  15 280  17 278  18 278  19 278  20
#  278  21 277  22 276  22 275  22 274  23 274  24 274  25 270  26 271  26
#  272  28 272  28 271  29 269  29 267  29 266  30 264  30 263  30 262  32
#  261  32 260  33 260  33 260  36 260  36 260  38 259  39 260  42 263  42
#  264  43 264  45 261  45 261  46 263  48 263  49 262  50 265  51 267  52
#  269  53 266  55 264  56 264  58 264  58 266  59 267  60 266  60 263  61
#  264  65 267  67 267  67 265  68 264  67 263  68 265  70 266  70 265  73
#  263  73 262  72 261  72 260  72 258  72 257  73 257  78 255  79 253  79
#  252  79 250  77 249  78 249 108 251 110 256 112 259 114 261 115 262 114
#  264 111 267 111 267 108 266 106 265 104 264 103 266 101 268 100 268  97
#  268  96 266  96 263  95 263  93 265  92 266  91 267  91 267  89 267  88
#  269  87 270  90 270  92 272  91 274  91 275  92 276  93 275  94 275  95
#  273  96 273  97 273 100 273 102 274 103 274 105 274 106 274 106 274 107
#  274 108 275 110 276 111 278 112 278 112 280 111 283 110 284 109 284 107
#  284 106 286 104 288 103 287 101 290 102 290 106 291 106 291 109 292 110
#  293 113 293 113 298 117 302 117 304 117 311 117 312 116 327 113 332 112
#  335 110 335 106 335 104 332 104 339 102 339 101 339  99 339  97 320  97
#  315  11 314   8 313   8" style="fill:gold; stroke:gold; stroke-width:1; fill-opacity:0.5" /><polygon points="309   0 312 117 318 125 320 116 320  97 339  97 345  99 346 121 365 122
#  376 124 394 125 421 124 479 141 599 134 599   0" style="fill:orchid; stroke:orchid; stroke-width:1; fill-opacity:0.5" /><polygon points="191  94 192 127 190 125 190 121 189  96 189  95" style="fill:slateblue; stroke:slateblue; stroke-width:1; fill-opacity:0.5" /><polygon points="  7  77   8 107  18 108  22 107  26 105  26  99  21  99  21  84  18  84
#   18  77" style="fill:limegreen; stroke:limegreen; stroke-width:1; fill-opacity:0.5" /><polygon points=" 20  79  21 132  18 131  16  79" style="fill:seagreen; stroke:seagreen; stroke-width:1; fill-opacity:0.5" /><polygon points=" 94 140  96 138  97 137  97 130  97 125  97 123  99 120 101 118 101 117
#  103 115 106 114 106 116 106 118 105 121 104 122 106 124 106 132 106 137
#  106 141 106 142 108 142 107 144 104 144 103 144 103 143 103 136 101 138
#   99 140  97 141  97 143  96 142" style="fill:darkgreen; stroke:darkgreen; stroke-width:1; fill-opacity:0.5" /><polygon points="109 135 109 144 113 145 114 145 117 144 118 135 116 133 110 133" style="fill:olive; stroke:olive; stroke-width:1; fill-opacity:0.5" /><polygon points="116 128 113 125 113  91 117  91 116 106 117 106 117 125" style="fill:teal; stroke:teal; stroke-width:1; fill-opacity:0.5" /><polygon points="108  95 108 105 111 106 114 108 119 107 122 103 124 100 124  97 123  95
#  122  93 120  93 117  93 116  94 114  93 110  93" style="fill:aquamarine; stroke:aquamarine; stroke-width:1; fill-opacity:0.5" /><polygon points="113 107 114 110 116 113 118 113 120 111 121 108 121 106 120 105 119 104
#  117 103 115 104 114 106" style="fill:steelblue; stroke:steelblue; stroke-width:1; fill-opacity:0.5" /><polygon points="160  40 144  42 143  42 142  42 139  42 137  41 134  42 134  44 133  45
#  128  45 127  45 126  46 127  49 127  52 130  52 128  53 130  55 132  58
#  133  59 130  60 128  64 128  67 130  68 130  69 129  71 128  73 127  76
#  127  78 124  81 127  82 127  83 126  85 125  88 124  91 124  93 123  96
#  125  97 127  96 130  97 135  96 138  97 139  97 141  95 144  94 147  95
#  150  96 152  99 154 101 154 104 158 106 161 108 166 108 173 112 178 112
#  179 110 179 106 181 104 182 104 185 103 186 101 189  99 190  99 193  97
#  196  95 199  94 200  94 202  95 207  93 209  93 212  92 213  93 215  95
#  217  94 219  93 220  93 221  91 221  90 223  89 224  87 222  87 222  85
#  221  83 222  82 222  80 222  79 223  76 225  77 226  77 226  76 230  75
#  229  73 227  72 225  72 223  70 220  68 222  66 224  65 224  64 223  63
#  222  61 222  60 220  60 218  61 213  60 215  58 216  56 217  55 220  53
#  221  52 223  49 225  46 223  46 222  46 220  45 218  45 218  46 216  44
#  214  43 215  39 216  36 214  35 213  34 212  33 212  33 210  35 210  31
#  209  29 209  28 208  26 205  27 205  29 203  27 204  25 202  23 201  20
#  199  20 197  18 196  20 195  25 195  26 194  29 192  30 195  32 195  35
#  192  36 191  35 189  34 188  33 186  33 185  33 182  36 181  35 179  34
#  179  32 181  29 181  28 178  27 173  32 168  37" style="fill:powderblue; stroke:powderblue; stroke-width:1; fill-opacity:0.5" /><polygon points="134  72 134  75 134  76 137  76 138 127 139 128 139 124 139  77 139  76
#  140  75 140  75 141  74 142  75 142  77 141  77 141  79 141  80 142  81
#  144  80 145  79 144  78 144  77 144  74 143  72 140  73 138  72 138  71
#  135  71" style="fill:dodgerblue; stroke:dodgerblue; stroke-width:1; fill-opacity:0.5" /><polygon points="135 101 136 106 142 106 142 102 142 101" style="fill:navy; stroke:navy; stroke-width:1; fill-opacity:0.5" /><polygon points="163  58 155  64 152  68 148  74 148  82 151  90 158  96 172  99 176  97
#  182  94 187  87 189  82 189  77 188  71 185  66 181  62 176  60 167  58" style="fill:magenta; stroke:magenta; stroke-width:1; fill-opacity:0.5" /><polygon points="206 184 202 134 199 132   0 159   0 277 165 203" style="fill:sienna; stroke:sienna; stroke-width:1; fill-opacity:0.5" /><polygon points="  0 127  21 127 192 121 194 120 195 133 185 134 185 130   0 147" style="fill:maroon; stroke:maroon; stroke-width:1; fill-opacity:0.5" /><polygon points="158   5 161 202 179 199 172   4" style="fill:white; stroke:white; stroke-width:1; fill-opacity:0.5" /><polygon points="179   0 179  22 149  24 147  22 147   0" style="fill:white; stroke:white; stroke-width:1; fill-opacity:0.5" /><polygon points="144  42 145  49 148  55 152
